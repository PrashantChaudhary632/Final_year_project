# %%
import simpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Simulation parameters
SIM_DURATION = 30 * 12 * 60  # 30 days, 12 hours per day (8 AM to 8 PM)
CAPACITY = 250
WILLINGNESS_TO_VISIT = 0.80  # 80% willingness to visit

# Arrival rates based on the day of the week and time slots
ARRIVAL_RATES = {
    'Sunday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Monday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Tuesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Wednesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Thursday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Friday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)],
    'Saturday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)]
}

# Initialize data for tracking arrivals, inter-arrival times, parking durations, revenue, and parking space utilization
arrival_pattern = np.zeros((30, 12))  # 30 days, 12 hours per day (8 AM to 8 PM)
inter_arrival_times = [[] for _ in range(30 * 12)]  # List of lists for storing inter-arrival times for each time slot
parking_durations = []  # List to store parking durations
total_revenue = 0  # Total revenue accumulator
lost_customers = 0  # Lost customers accumulator
parked_customers = 0  # Parked customers accumulator
utilization_data = []  # List to store occupancy data for utilization calculation

def get_arrival_rate(day, hour):
    """Return the arrival rate based on the day and hour."""
    for start, end, rate in ARRIVAL_RATES[day]:
        if start <= hour < end:
            return rate
    return 0

def calculate_charge(parking_duration):
    """Calculate the charge based on parking duration with ceiling logic."""
    if parking_duration < 30:
        return 15
    else:
        hours = np.ceil(parking_duration / 60)  # Round up to the nearest hour
        return 25 * hours  # Charge ₹25 per hour

def vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time):
    """Simulates vehicle parking behavior, tracks arrivals, inter-arrival times, and calculates revenue."""
    global total_revenue, lost_customers, parked_customers
    
    # Check if the vehicle decides to park based on willingness to visit
    if np.random.random() > WILLINGNESS_TO_VISIT:
        lost_customers += 1
        return  # Vehicle leaves without parking

    # Generate parking duration (in minutes)
    parking_duration = np.random.exponential(60)  # Exponential distribution with mean 60 minutes
    
    # Store parking duration
    parking_durations.append(parking_duration)
    
    # Calculate the charge based on parking duration
    charge = calculate_charge(parking_duration)
    
    # Print the charge for debugging
    print(f"Parking Duration: {parking_duration:.2f} minutes, Charge: ₹{charge:.2f}")
    
    # Update total revenue
    total_revenue += charge
    parked_customers += 1  # Increment parked customers counter
    
    with parking_lot.request() as request:
        yield request
        # Update occupancy data
        current_time = env.now
        num_vehicles = len(parking_lot.users)
        utilization_data.append((current_time, num_vehicles))
        yield env.timeout(parking_duration)
        # Track arrivals for the specific day and hour
        arrival_pattern[day_index, hour_index] += 1  # Use correct indexing for Numpy arrays
        # Store the inter-arrival time
        inter_arrival_times[day_index * 12 + hour_index].append(inter_arrival_time)

def arrival_process(env, parking_lot, day, day_index):
    """Simulates the arrival process based on the day and time."""
    global parked_customers, lost_customers
    while env.now < (day_index + 1) * 12 * 60:  # Simulate only 12 hours per day
        current_hour = (env.now // 60) % 12 + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
        rate = get_arrival_rate(day, current_hour)
        
        # Determine the hour index (0 to 11 for 8 AM to 8 PM)
        hour_index = int(current_hour - 8)  # Adjust index to match 0-11 range
        
        if 0 <= hour_index < 12:  # Ensure hour_index is within valid bounds
            if rate > 0:
                inter_arrival_time = np.random.exponential(60 / rate)  # Convert hourly rate to inter-arrival time
                yield env.timeout(inter_arrival_time)
                env.process(vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time))
            else:
                yield env.timeout(1)  # Wait for 1 minute if no arrival

def run_simulation():
    """Runs the simulation for 30 days."""
    global total_revenue, lost_customers, parked_customers
    env = simpy.Environment()
    parking_lot = simpy.Resource(env, capacity=CAPACITY)

    for day_index in range(30):
        day_name = list(ARRIVAL_RATES.keys())[day_index % 7]  # Cycle through days of the week
        env.process(arrival_process(env, parking_lot, day_name, day_index))

        # Simulate 12 hours of the current day
        env.run(until=(day_index + 1) * 12 * 60)

# Run the simulation
run_simulation()

# Calculate average inter-arrival time for each time slot
average_inter_arrival = np.zeros((30, 12))  # 30 days, 12 hours per day

for i in range(30):
    for j in range(12):
        if inter_arrival_times[i * 12 + j]:  # Check if there are any inter-arrival times recorded
            average_inter_arrival[i, j] = np.mean(inter_arrival_times[i * 12 + j])

# Create DataFrames for the heatmaps
hours = [f"{hour}:00" for hour in range(8, 20)]  # Hour labels from 8 AM to 8 PM
days = [f"Day {i+1}" for i in range(30)]
arrival_df = pd.DataFrame(arrival_pattern, index=days, columns=hours)
average_inter_arrival_df = pd.DataFrame(average_inter_arrival, index=days, columns=hours)

# Print arrival pattern, average inter-arrival time, total revenue, and time slot utilization
print("Parking Arrival Pattern Over 30 Days:")
print(arrival_df)
print("\nAverage Inter-Arrival Time (in minutes) Over 30 Days:")
print(average_inter_arrival_df)

# Calculate parking space utilization for each time slot
time_slot_utilization = {
    '8-11:59': [],
    '12-16:59': [],
    '17-20:00': []
}

# Utility function to get time slot based on the hour
def get_time_slot(hour):
    if 8 <= hour < 12:
        return '8-11:59'
    elif 12 <= hour < 17:
        return '12-16:59'
    elif 17 <= hour < 20:
        return '17-20:00'
    return None

# Compute the total occupied time based on occupancy data and categorize by time slots
previous_time = 0  # Reset previous_time before usage
for current_time, num_vehicles in utilization_data:
    hour = int((current_time // 60) % 12) + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
    time_slot = get_time_slot(hour)
    if time_slot:
        time_spent = current_time - previous_time
        time_slot_utilization[time_slot].append(time_spent * (num_vehicles / CAPACITY))
    previous_time = current_time

# Calculate average utilization for each time slot
total_time_per_slot = {
    '8-11:59': 4 * 60 * 30,  # 4 hours per day, 30 days
    '12-16:59': 5 * 60 * 30,  # 5 hours per day, 30 days
    '17-20:00': 3 * 60 * 30   # 3 hours per day, 30 days
}

average_utilization_by_slot = {
    slot: (np.sum(time_slot_utilization[slot]) / total_time_per_slot[slot]) * 100
    for slot in time_slot_utilization
}

# Print average parking space utilization by time slot
print("\nAverage Parking Space Utilization by Time Slot:")
for slot, utilization in average_utilization_by_slot.items():
    print(f"{slot}: {utilization:.2f}%")

# Calculate percentage of lost customers
total_attempted_arrivals = parked_customers + lost_customers
percentage_lost_customers = (lost_customers / total_attempted_arrivals) * 100 if total_attempted_arrivals > 0 else 0

# Print results
print(f"\nTotal Parked Customers: {parked_customers}")
print(f"Total Lost Customers: {lost_customers}")
print(f"Percentage of Lost Customers: {percentage_lost_customers:.2f}%")

# Plotting the heatmaps
plt.figure(figsize=(16, 12))

# Heatmap for parking arrival pattern
plt.subplot(1, 2, 1)
sns.heatmap(arrival_df, annot=True, cmap="YlGnBu", cbar=True, fmt=".0f")
plt.title("Parking Arrival Pattern Over 30 Days")
plt.xlabel("Hours")
plt.ylabel("Days")

# Heatmap for average inter-arrival time
plt.subplot(1, 2, 2)
sns.heatmap(average_inter_arrival_df, annot=True, cmap="YlGnBu", cbar=True, fmt=".1f")
plt.title("Average Inter-Arrival Time Over 30 Days")
plt.xlabel("Hours")
plt.ylabel("Days")

plt.tight_layout()
plt.show()

# Plot parking duration histogram
plt.figure(figsize=(12, 6))
max_duration = int(max(parking_durations))
bins = range(0, max_duration + 10, 20)  # Create bins with 10-minute intervals
plt.hist(parking_durations, bins=bins, edgecolor='black', linewidth=1.5)  # Increased linewidth

# Customizing x-ticks to show intervals of 10 minutes
plt.xticks(bins)

plt.title("Histogram of Parking Durations")
plt.xlabel("Parking Duration (minutes)")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines for better readability

plt.show()

# Calculate lost revenue
lost_revenue = lost_customers * 15  # Assuming average charge for a vehicle is ₹15

print(f"\nTotal Revenue Over 30 Days: ₹{total_revenue:.2f}")
print(f"Total Lost Revenue Due to Lost Customers: ₹{lost_revenue:.2f}")
# Out:
# Parking Duration: 36.26 minutes, Charge: ₹25.00
# Parking Duration: 155.89 minutes, Charge: ₹75.00
# Parking Duration: 5.02 minutes, Charge: ₹15.00
# Parking Duration: 4.84 minutes, Charge: ₹15.00
# Parking Duration: 21.47 minutes, Charge: ₹15.00
# Parking Duration: 7.95 minutes, Charge: ₹15.00
# Parking Duration: 3.18 minutes, Charge: ₹15.00
# Parking Duration: 49.28 minutes, Charge: ₹25.00
# Parking Duration: 169.50 minutes, Charge: ₹75.00
# Parking Duration: 58.09 minutes, Charge: ₹25.00
# Parking Duration: 197.79 minutes, Charge: ₹100.00
# Parking Duration: 95.34 minutes, Charge: ₹50.00
# Parking Duration: 134.72 minutes, Charge: ₹75.00
# Parking Duration: 51.12 minutes, Charge: ₹25.00
# Parking Duration: 61.21 minutes, Charge: ₹50.00
# Parking Duration: 10.87 minutes, Charge: ₹15.00
# Parking Duration: 11.51 minutes, Charge: ₹15.00
# Parking Duration: 13.22 minutes, Charge: ₹15.00
# Parking Duration: 35.29 minutes, Charge: ₹25.00
# Parking Duration: 75.26 minutes, Charge: ₹50.00
# Parking Duration: 81.68 minutes, Charge: ₹50.00
# Parking Duration: 17.02 minutes, Charge: ₹15.00
# Parking Duration: 13.23 minutes, Charge: ₹15.00
# Parking Duration: 73.40 minutes, Charge: ₹50.00
# Parking Duration: 96.58 minutes, Charge: ₹50.00
# Parking Duration: 60.03 minutes, Charge: ₹50.00
# Parking Duration: 8.10 minutes, Charge: ₹15.00
# Parking Duration: 33.46 minutes, Charge: ₹25.00
# Parking Duration: 45.11 minutes, Charge: ₹25.00
# Parking Duration: 56.94 minutes, Charge: ₹25.00
# Parking Duration: 17.03 minutes, Charge: ₹15.00
# Parking Duration: 72.16 minutes, Charge: ₹50.00
# Parking Duration: 1.77 minutes, Charge: ₹15.00
# Parking Duration: 78.70 minutes, Charge: ₹50.00
# Parking Duration: 31.46 minutes, Charge: ₹25.00
# Parking Duration: 81.82 minutes, Charge: ₹50.00
# Parking Duration: 4.48 minutes, Charge: ₹15.00
# Parking Duration: 127.16 minutes, Charge: ₹75.00
# Parking Duration: 6.14 minutes, Charge: ₹15.00
# Parking Duration: 37.62 minutes, Charge: ₹25.00
# Parking Duration: 19.75 minutes, Charge: ₹15.00
# Parking Duration: 19.13 minutes, Charge: ₹15.00
# Parking Duration: 39.77 minutes, Charge: ₹25.00
# Parking Duration: 28.16 minutes, Charge: ₹15.00
# Parking Duration: 11.52 minutes, Charge: ₹15.00
# Parking Duration: 42.97 minutes, Charge: ₹25.00
# Parking Duration: 42.96 minutes, Charge: ₹25.00
# Parking Duration: 56.41 minutes, Charge: ₹25.00
# Parking Duration: 142.18 minutes, Charge: ₹75.00
# Parking Duration: 9.87 minutes, Charge: ₹15.00
# Parking Duration: 120.44 minutes, Charge: ₹75.00
# Parking Duration: 19.86 minutes, Charge: ₹15.00
# Parking Duration: 78.22 minutes, Charge: ₹50.00
# Parking Duration: 11.27 minutes, Charge: ₹15.00
# Parking Duration: 34.92 minutes, Charge: ₹25.00
# Parking Duration: 301.71 minutes, Charge: ₹150.00
# Parking Duration: 19.72 minutes, Charge: ₹15.00
# Parking Duration: 106.25 minutes, Charge: ₹50.00
# Parking Duration: 23.80 minutes, Charge: ₹15.00
# Parking Duration: 25.98 minutes, Charge: ₹15.00
# Parking Duration: 4.98 minutes, Charge: ₹15.00
# Parking Duration: 371.66 minutes, Charge: ₹175.00
# Parking Duration: 12.48 minutes, Charge: ₹15.00
# Parking Duration: 27.42 minutes, Charge: ₹15.00
# Parking Duration: 294.15 minutes, Charge: ₹125.00
# Parking Duration: 19.30 minutes, Charge: ₹15.00
# Parking Duration: 50.53 minutes, Charge: ₹25.00
# Parking Duration: 85.81 minutes, Charge: ₹50.00
# Parking Duration: 12.14 minutes, Charge: ₹15.00
# Parking Duration: 57.33 minutes, Charge: ₹25.00
# Parking Duration: 10.39 minutes, Charge: ₹15.00
# Parking Duration: 105.28 minutes, Charge: ₹50.00
# Parking Duration: 13.93 minutes, Charge: ₹15.00
# Parking Duration: 8.35 minutes, Charge: ₹15.00
# Parking Duration: 162.10 minutes, Charge: ₹75.00
# Parking Duration: 78.54 minutes, Charge: ₹50.00
# Parking Duration: 72.41 minutes, Charge: ₹50.00
# Parking Duration: 124.04 minutes, Charge: ₹75.00
# Parking Duration: 62.69 minutes, Charge: ₹50.00
# Parking Duration: 14.14 minutes, Charge: ₹15.00
# Parking Duration: 55.90 minutes, Charge: ₹25.00
# Parking Duration: 31.64 minutes, Charge: ₹25.00
# Parking Duration: 294.23 minutes, Charge: ₹125.00
# Parking Duration: 182.86 minutes, Charge: ₹100.00
# Parking Duration: 41.65 minutes, Charge: ₹25.00
# Parking Duration: 31.80 minutes, Charge: ₹25.00
# Parking Duration: 190.59 minutes, Charge: ₹100.00
# Parking Duration: 6.45 minutes, Charge: ₹15.00
# Parking Duration: 48.82 minutes, Charge: ₹25.00
# Parking Duration: 255.84 minutes, Charge: ₹125.00
# Parking Duration: 224.71 minutes, Charge: ₹100.00
# Parking Duration: 95.80 minutes, Charge: ₹50.00
# Parking Duration: 142.59 minutes, Charge: ₹75.00
# Parking Duration: 59.58 minutes, Charge: ₹25.00
# Parking Duration: 262.85 minutes, Charge: ₹125.00
# Parking Duration: 149.43 minutes, Charge: ₹75.00
# Parking Duration: 82.10 minutes, Charge: ₹50.00
# Parking Duration: 107.16 minutes, Charge: ₹50.00
# Parking Duration: 46.02 minutes, Charge: ₹25.00
# Parking Duration: 29.14 minutes, Charge: ₹15.00
# Parking Duration: 117.85 minutes, Charge: ₹50.00
# Parking Duration: 87.93 minutes, Charge: ₹50.00
# Parking Duration: 18.01 minutes, Charge: ₹15.00
# Parking Duration: 78.57 minutes, Charge: ₹50.00
# Parking Duration: 92.97 minutes, Charge: ₹50.00
# Parking Duration: 46.81 minutes, Charge: ₹25.00
# Parking Duration: 163.11 minutes, Charge: ₹75.00
# Parking Duration: 19.17 minutes, Charge: ₹15.00
# Parking Duration: 200.05 minutes, Charge: ₹100.00
# Parking Duration: 1.81 minutes, Charge: ₹15.00
# Parking Duration: 62.94 minutes, Charge: ₹50.00
# Parking Duration: 38.45 minutes, Charge: ₹25.00
# Parking Duration: 43.62 minutes, Charge: ₹25.00
# Parking Duration: 32.17 minutes, Charge: ₹25.00
# Parking Duration: 53.85 minutes, Charge: ₹25.00
# Parking Duration: 106.13 minutes, Charge: ₹50.00
# Parking Duration: 177.75 minutes, Charge: ₹75.00
# Parking Duration: 29.52 minutes, Charge: ₹15.00
# Parking Duration: 64.67 minutes, Charge: ₹50.00
# Parking Duration: 44.24 minutes, Charge: ₹25.00
# Parking Duration: 34.11 minutes, Charge: ₹25.00
# Parking Duration: 66.45 minutes, Charge: ₹50.00
# Parking Duration: 9.54 minutes, Charge: ₹15.00
# Parking Duration: 45.57 minutes, Charge: ₹25.00
# Parking Duration: 10.44 minutes, Charge: ₹15.00
# Parking Duration: 26.07 minutes, Charge: ₹15.00
# Parking Duration: 71.79 minutes, Charge: ₹50.00
# Parking Duration: 125.88 minutes, Charge: ₹75.00
# Parking Duration: 40.31 minutes, Charge: ₹25.00
# Parking Duration: 116.98 minutes, Charge: ₹50.00
# Parking Duration: 20.92 minutes, Charge: ₹15.00
# Parking Duration: 60.29 minutes, Charge: ₹50.00
# Parking Duration: 42.83 minutes, Charge: ₹25.00
# Parking Duration: 13.27 minutes, Charge: ₹15.00
# Parking Duration: 123.13 minutes, Charge: ₹75.00
# Parking Duration: 32.22 minutes, Charge: ₹25.00
# Parking Duration: 156.09 minutes, Charge: ₹75.00
# Parking Duration: 95.50 minutes, Charge: ₹50.00
# Parking Duration: 27.55 minutes, Charge: ₹15.00
# Parking Duration: 141.72 minutes, Charge: ₹75.00
# Parking Duration: 59.41 minutes, Charge: ₹25.00
# Parking Duration: 68.06 minutes, Charge: ₹50.00
# Parking Duration: 53.46 minutes, Charge: ₹25.00
# Parking Duration: 70.50 minutes, Charge: ₹50.00
# Parking Duration: 51.64 minutes, Charge: ₹25.00
# Parking Duration: 45.03 minutes, Charge: ₹25.00
# Parking Duration: 43.99 minutes, Charge: ₹25.00
# Parking Duration: 103.50 minutes, Charge: ₹50.00
# Parking Duration: 49.03 minutes, Charge: ₹25.00
# Parking Duration: 69.60 minutes, Charge: ₹50.00
# Parking Duration: 5.64 minutes, Charge: ₹15.00
# Parking Duration: 49.40 minutes, Charge: ₹25.00
# Parking Duration: 52.06 minutes, Charge: ₹25.00
# Parking Duration: 133.97 minutes, Charge: ₹75.00
# Parking Duration: 43.87 minutes, Charge: ₹25.00
# Parking Duration: 25.92 minutes, Charge: ₹15.00
# Parking Duration: 5.49 minutes, Charge: ₹15.00
# Parking Duration: 33.04 minutes, Charge: ₹25.00
# Parking Duration: 7.02 minutes, Charge: ₹15.00
# Parking Duration: 8.42 minutes, Charge: ₹15.00
# Parking Duration: 42.11 minutes, Charge: ₹25.00
# Parking Duration: 151.79 minutes, Charge: ₹75.00
# Parking Duration: 51.39 minutes, Charge: ₹25.00
# Parking Duration: 134.42 minutes, Charge: ₹75.00
# Parking Duration: 29.42 minutes, Charge: ₹15.00
# Parking Duration: 7.83 minutes, Charge: ₹15.00
# Parking Duration: 176.84 minutes, Charge: ₹75.00
# Parking Duration: 76.41 minutes, Charge: ₹50.00
# Parking Duration: 103.49 minutes, Charge: ₹50.00
# Parking Duration: 1.37 minutes, Charge: ₹15.00
# Parking Duration: 30.49 minutes, Charge: ₹25.00
# Parking Duration: 131.30 minutes, Charge: ₹75.00
# Parking Duration: 1.03 minutes, Charge: ₹15.00
# Parking Duration: 70.21 minutes, Charge: ₹50.00
# Parking Duration: 16.52 minutes, Charge: ₹15.00
# Parking Duration: 17.80 minutes, Charge: ₹15.00
# Parking Duration: 131.76 minutes, Charge: ₹75.00
# Parking Duration: 88.32 minutes, Charge: ₹50.00
# Parking Duration: 5.49 minutes, Charge: ₹15.00
# Parking Duration: 55.05 minutes, Charge: ₹25.00
# Parking Duration: 199.66 minutes, Charge: ₹100.00
# Parking Duration: 12.49 minutes, Charge: ₹15.00
# Parking Duration: 10.40 minutes, Charge: ₹15.00
# Parking Duration: 42.03 minutes, Charge: ₹25.00
# Parking Duration: 2.52 minutes, Charge: ₹15.00
# Parking Duration: 64.29 minutes, Charge: ₹50.00
# Parking Duration: 141.01 minutes, Charge: ₹75.00
# Parking Duration: 41.70 minutes, Charge: ₹25.00
# Parking Duration: 72.99 minutes, Charge: ₹50.00
# Parking Duration: 124.04 minutes, Charge: ₹75.00
# Parking Duration: 133.47 minutes, Charge: ₹75.00
# Parking Duration: 9.49 minutes, Charge: ₹15.00
# Parking Duration: 37.89 minutes, Charge: ₹25.00
# Parking Duration: 225.49 minutes, Charge: ₹100.00
# Parking Duration: 59.16 minutes, Charge: ₹25.00
# Parking Duration: 54.24 minutes, Charge: ₹25.00
# Parking Duration: 71.25 minutes, Charge: ₹50.00
# Parking Duration: 83.14 minutes, Charge: ₹50.00
# Parking Duration: 9.92 minutes, Charge: ₹15.00
# Parking Duration: 139.70 minutes, Charge: ₹75.00
# Parking Duration: 8.74 minutes, Charge: ₹15.00
# Parking Duration: 36.88 minutes, Charge: ₹25.00
# Parking Duration: 19.32 minutes, Charge: ₹15.00
# Parking Duration: 288.65 minutes, Charge: ₹125.00
# Parking Duration: 38.92 minutes, Charge: ₹25.00
# Parking Duration: 56.81 minutes, Charge: ₹25.00
# Parking Duration: 83.90 minutes, Charge: ₹50.00
# Parking Duration: 14.64 minutes, Charge: ₹15.00
# Parking Duration: 233.10 minutes, Charge: ₹100.00
# Parking Duration: 107.43 minutes, Charge: ₹50.00
# Parking Duration: 21.40 minutes, Charge: ₹15.00
# Parking Duration: 36.12 minutes, Charge: ₹25.00
# Parking Duration: 100.78 minutes, Charge: ₹50.00
# Parking Duration: 102.03 minutes, Charge: ₹50.00
# Parking Duration: 203.49 minutes, Charge: ₹100.00
# Parking Duration: 22.24 minutes, Charge: ₹15.00
# Parking Duration: 114.02 minutes, Charge: ₹50.00
# Parking Duration: 2.06 minutes, Charge: ₹15.00
# Parking Duration: 49.65 minutes, Charge: ₹25.00
# Parking Duration: 12.75 minutes, Charge: ₹15.00
# Parking Duration: 26.59 minutes, Charge: ₹15.00
# Parking Duration: 90.79 minutes, Charge: ₹50.00
# Parking Duration: 94.14 minutes, Charge: ₹50.00
# Parking Duration: 4.28 minutes, Charge: ₹15.00
# Parking Duration: 11.85 minutes, Charge: ₹15.00
# Parking Duration: 31.95 minutes, Charge: ₹25.00
# Parking Duration: 32.49 minutes, Charge: ₹25.00
# Parking Duration: 200.26 minutes, Charge: ₹100.00
# Parking Duration: 23.62 minutes, Charge: ₹15.00
# Parking Duration: 14.70 minutes, Charge: ₹15.00
# Parking Duration: 14.09 minutes, Charge: ₹15.00
# Parking Duration: 9.34 minutes, Charge: ₹15.00
# Parking Duration: 20.47 minutes, Charge: ₹15.00
# Parking Duration: 46.89 minutes, Charge: ₹25.00
# Parking Duration: 28.58 minutes, Charge: ₹15.00
# Parking Duration: 244.59 minutes, Charge: ₹125.00
# Parking Duration: 24.26 minutes, Charge: ₹15.00
# Parking Duration: 172.13 minutes, Charge: ₹75.00
# Parking Duration: 92.86 minutes, Charge: ₹50.00
# Parking Duration: 0.51 minutes, Charge: ₹15.00
# Parking Duration: 70.80 minutes, Charge: ₹50.00
# Parking Duration: 16.96 minutes, Charge: ₹15.00
# Parking Duration: 52.43 minutes, Charge: ₹25.00
# Parking Duration: 10.27 minutes, Charge: ₹15.00
# Parking Duration: 80.64 minutes, Charge: ₹50.00
# Parking Duration: 40.86 minutes, Charge: ₹25.00
# Parking Duration: 114.94 minutes, Charge: ₹50.00
# Parking Duration: 24.36 minutes, Charge: ₹15.00
# Parking Duration: 22.38 minutes, Charge: ₹15.00
# Parking Duration: 151.49 minutes, Charge: ₹75.00
# Parking Duration: 116.23 minutes, Charge: ₹50.00
# Parking Duration: 3.74 minutes, Charge: ₹15.00
# Parking Duration: 3.11 minutes, Charge: ₹15.00
# Parking Duration: 87.17 minutes, Charge: ₹50.00
# Parking Duration: 24.15 minutes, Charge: ₹15.00
# Parking Duration: 41.09 minutes, Charge: ₹25.00
# Parking Duration: 24.85 minutes, Charge: ₹15.00
# Parking Duration: 4.88 minutes, Charge: ₹15.00
# Parking Duration: 162.62 minutes, Charge: ₹75.00
# Parking Duration: 18.49 minutes, Charge: ₹15.00
# Parking Duration: 33.25 minutes, Charge: ₹25.00
# Parking Duration: 116.49 minutes, Charge: ₹50.00
# Parking Duration: 24.83 minutes, Charge: ₹15.00
# Parking Duration: 78.34 minutes, Charge: ₹50.00
# Parking Duration: 0.93 minutes, Charge: ₹15.00
# Parking Duration: 26.59 minutes, Charge: ₹15.00
# Parking Duration: 48.23 minutes, Charge: ₹25.00
# Parking Duration: 19.34 minutes, Charge: ₹15.00
# Parking Duration: 57.41 minutes, Charge: ₹25.00
# Parking Duration: 92.27 minutes, Charge: ₹50.00
# Parking Duration: 35.63 minutes, Charge: ₹25.00
# Parking Duration: 5.35 minutes, Charge: ₹15.00
# Parking Duration: 52.40 minutes, Charge: ₹25.00
# Parking Duration: 39.52 minutes, Charge: ₹25.00
# Parking Duration: 90.77 minutes, Charge: ₹50.00
# Parking Duration: 3.86 minutes, Charge: ₹15.00
# Parking Duration: 107.07 minutes, Charge: ₹50.00
# Parking Duration: 178.70 minutes, Charge: ₹75.00
# Parking Duration: 326.27 minutes, Charge: ₹150.00
# Parking Duration: 82.42 minutes, Charge: ₹50.00
# Parking Duration: 31.21 minutes, Charge: ₹25.00
# Parking Duration: 13.30 minutes, Charge: ₹15.00
# Parking Duration: 11.04 minutes, Charge: ₹15.00
# Parking Duration: 37.79 minutes, Charge: ₹25.00
# Parking Duration: 59.48 minutes, Charge: ₹25.00
# Parking Duration: 22.50 minutes, Charge: ₹15.00
# Parking Duration: 2.62 minutes, Charge: ₹15.00
# Parking Duration: 10.54 minutes, Charge: ₹15.00
# Parking Duration: 3.00 minutes, Charge: ₹15.00
# Parking Duration: 102.38 minutes, Charge: ₹50.00
# Parking Duration: 19.04 minutes, Charge: ₹15.00
# Parking Duration: 43.73 minutes, Charge: ₹25.00
# Parking Duration: 13.49 minutes, Charge: ₹15.00
# Parking Duration: 38.03 minutes, Charge: ₹25.00
# Parking Duration: 38.00 minutes, Charge: ₹25.00
# Parking Duration: 13.85 minutes, Charge: ₹15.00
# Parking Duration: 233.13 minutes, Charge: ₹100.00
# Parking Duration: 162.21 minutes, Charge: ₹75.00
# Parking Duration: 9.58 minutes, Charge: ₹15.00
# Parking Duration: 142.99 minutes, Charge: ₹75.00
# Parking Duration: 17.07 minutes, Charge: ₹15.00
# Parking Duration: 54.30 minutes, Charge: ₹25.00
# Parking Duration: 26.84 minutes, Charge: ₹15.00
# Parking Duration: 6.07 minutes, Charge: ₹15.00
# Parking Duration: 16.65 minutes, Charge: ₹15.00
# Parking Duration: 70.38 minutes, Charge: ₹50.00
# Parking Duration: 118.65 minutes, Charge: ₹50.00
# Parking Duration: 35.74 minutes, Charge: ₹25.00
# Parking Duration: 60.30 minutes, Charge: ₹50.00
# Parking Duration: 31.93 minutes, Charge: ₹25.00
# Parking Duration: 19.33 minutes, Charge: ₹15.00
# Parking Duration: 106.98 minutes, Charge: ₹50.00
# Parking Duration: 11.63 minutes, Charge: ₹15.00
# Parking Duration: 30.27 minutes, Charge: ₹25.00
# Parking Duration: 11.27 minutes, Charge: ₹15.00
# Parking Duration: 110.09 minutes, Charge: ₹50.00
# Parking Duration: 29.66 minutes, Charge: ₹15.00
# Parking Duration: 6.00 minutes, Charge: ₹15.00
# Parking Duration: 177.39 minutes, Charge: ₹75.00
# Parking Duration: 65.45 minutes, Charge: ₹50.00
# Parking Duration: 56.17 minutes, Charge: ₹25.00
# Parking Duration: 8.56 minutes, Charge: ₹15.00
# Parking Duration: 5.22 minutes, Charge: ₹15.00
# Parking Duration: 102.09 minutes, Charge: ₹50.00
# Parking Duration: 10.10 minutes, Charge: ₹15.00
# Parking Duration: 164.90 minutes, Charge: ₹75.00
# Parking Duration: 39.59 minutes, Charge: ₹25.00
# Parking Duration: 23.31 minutes, Charge: ₹15.00
# Parking Duration: 67.58 minutes, Charge: ₹50.00
# Parking Duration: 1.00 minutes, Charge: ₹15.00
# Parking Duration: 11.17 minutes, Charge: ₹15.00
# Parking Duration: 16.60 minutes, Charge: ₹15.00
# Parking Duration: 11.32 minutes, Charge: ₹15.00
# Parking Duration: 8.55 minutes, Charge: ₹15.00
# Parking Duration: 44.99 minutes, Charge: ₹25.00
# Parking Duration: 42.02 minutes, Charge: ₹25.00
# Parking Duration: 88.62 minutes, Charge: ₹50.00
# Parking Duration: 30.87 minutes, Charge: ₹25.00
# Parking Duration: 18.09 minutes, Charge: ₹15.00
# Parking Duration: 10.86 minutes, Charge: ₹15.00
# Parking Duration: 19.26 minutes, Charge: ₹15.00
# Parking Duration: 117.28 minutes, Charge: ₹50.00
# Parking Duration: 11.40 minutes, Charge: ₹15.00
# Parking Duration: 10.53 minutes, Charge: ₹15.00
# Parking Duration: 65.74 minutes, Charge: ₹50.00
# Parking Duration: 144.86 minutes, Charge: ₹75.00
# Parking Duration: 44.12 minutes, Charge: ₹25.00
# Parking Duration: 109.78 minutes, Charge: ₹50.00
# Parking Duration: 4.85 minutes, Charge: ₹15.00
# Parking Duration: 60.10 minutes, Charge: ₹50.00
# Parking Duration: 38.95 minutes, Charge: ₹25.00
# Parking Duration: 4.90 minutes, Charge: ₹15.00
# Parking Duration: 129.71 minutes, Charge: ₹75.00
# Parking Duration: 9.87 minutes, Charge: ₹15.00
# Parking Duration: 97.94 minutes, Charge: ₹50.00
# Parking Duration: 86.69 minutes, Charge: ₹50.00
# Parking Duration: 51.62 minutes, Charge: ₹25.00
# Parking Duration: 118.58 minutes, Charge: ₹50.00
# Parking Duration: 57.05 minutes, Charge: ₹25.00
# Parking Duration: 15.62 minutes, Charge: ₹15.00
# Parking Duration: 15.90 minutes, Charge: ₹15.00
# Parking Duration: 102.20 minutes, Charge: ₹50.00
# Parking Duration: 17.74 minutes, Charge: ₹15.00
# Parking Duration: 104.09 minutes, Charge: ₹50.00
# Parking Duration: 36.61 minutes, Charge: ₹25.00
# Parking Duration: 3.46 minutes, Charge: ₹15.00
# Parking Duration: 9.04 minutes, Charge: ₹15.00
# Parking Duration: 40.60 minutes, Charge: ₹25.00
# Parking Duration: 4.31 minutes, Charge: ₹15.00
# Parking Duration: 60.91 minutes, Charge: ₹50.00
# Parking Duration: 77.63 minutes, Charge: ₹50.00
# Parking Duration: 7.15 minutes, Charge: ₹15.00
# Parking Duration: 3.21 minutes, Charge: ₹15.00
# Parking Duration: 63.34 minutes, Charge: ₹50.00
# Parking Duration: 11.21 minutes, Charge: ₹15.00
# Parking Duration: 110.16 minutes, Charge: ₹50.00
# Parking Duration: 78.87 minutes, Charge: ₹50.00
# Parking Duration: 49.18 minutes, Charge: ₹25.00
# Parking Duration: 65.34 minutes, Charge: ₹50.00
# Parking Duration: 340.64 minutes, Charge: ₹150.00
# Parking Duration: 16.31 minutes, Charge: ₹15.00
# Parking Duration: 4.78 minutes, Charge: ₹15.00
# Parking Duration: 13.61 minutes, Charge: ₹15.00
# Parking Duration: 9.44 minutes, Charge: ₹15.00
# Parking Duration: 55.48 minutes, Charge: ₹25.00
# Parking Duration: 8.38 minutes, Charge: ₹15.00
# Parking Duration: 91.66 minutes, Charge: ₹50.00
# Parking Duration: 32.11 minutes, Charge: ₹25.00
# Parking Duration: 150.80 minutes, Charge: ₹75.00
# Parking Duration: 13.80 minutes, Charge: ₹15.00
# Parking Duration: 9.18 minutes, Charge: ₹15.00
# Parking Duration: 190.79 minutes, Charge: ₹100.00
# Parking Duration: 67.23 minutes, Charge: ₹50.00
# Parking Duration: 0.11 minutes, Charge: ₹15.00
# Parking Duration: 57.03 minutes, Charge: ₹25.00
# Parking Duration: 53.97 minutes, Charge: ₹25.00
# Parking Duration: 13.02 minutes, Charge: ₹15.00
# Parking Duration: 24.04 minutes, Charge: ₹15.00
# Parking Duration: 50.22 minutes, Charge: ₹25.00
# Parking Duration: 101.30 minutes, Charge: ₹50.00
# Parking Duration: 83.38 minutes, Charge: ₹50.00
# Parking Duration: 121.02 minutes, Charge: ₹75.00
# Parking Duration: 107.89 minutes, Charge: ₹50.00
# Parking Duration: 7.63 minutes, Charge: ₹15.00
# Parking Duration: 54.62 minutes, Charge: ₹25.00
# Parking Duration: 19.86 minutes, Charge: ₹15.00
# Parking Duration: 133.92 minutes, Charge: ₹75.00
# Parking Duration: 0.54 minutes, Charge: ₹15.00
# Parking Duration: 91.85 minutes, Charge: ₹50.00
# Parking Duration: 64.08 minutes, Charge: ₹50.00
# Parking Duration: 38.02 minutes, Charge: ₹25.00
# Parking Duration: 135.39 minutes, Charge: ₹75.00
# Parking Duration: 57.86 minutes, Charge: ₹25.00
# Parking Duration: 83.32 minutes, Charge: ₹50.00
# Parking Duration: 69.10 minutes, Charge: ₹50.00
# Parking Duration: 32.13 minutes, Charge: ₹25.00
# Parking Duration: 162.15 minutes, Charge: ₹75.00
# Parking Duration: 74.17 minutes, Charge: ₹50.00
# Parking Duration: 46.82 minutes, Charge: ₹25.00
# Parking Duration: 58.27 minutes, Charge: ₹25.00
# Parking Duration: 25.44 minutes, Charge: ₹15.00
# Parking Duration: 3.03 minutes, Charge: ₹15.00
# Parking Duration: 94.69 minutes, Charge: ₹50.00
# Parking Duration: 119.62 minutes, Charge: ₹50.00
# Parking Duration: 118.04 minutes, Charge: ₹50.00
# Parking Duration: 79.44 minutes, Charge: ₹50.00
# Parking Duration: 44.48 minutes, Charge: ₹25.00
# Parking Duration: 25.05 minutes, Charge: ₹15.00
# Parking Duration: 9.93 minutes, Charge: ₹15.00
# Parking Duration: 54.83 minutes, Charge: ₹25.00
# Parking Duration: 53.77 minutes, Charge: ₹25.00
# Parking Duration: 86.08 minutes, Charge: ₹50.00
# Parking Duration: 94.92 minutes, Charge: ₹50.00
# Parking Duration: 140.00 minutes, Charge: ₹75.00
# Parking Duration: 192.48 minutes, Charge: ₹100.00
# Parking Duration: 125.55 minutes, Charge: ₹75.00
# Parking Duration: 17.70 minutes, Charge: ₹15.00
# Parking Duration: 107.73 minutes, Charge: ₹50.00
# Parking Duration: 22.57 minutes, Charge: ₹15.00
# Parking Duration: 60.25 minutes, Charge: ₹50.00
# Parking Duration: 92.22 minutes, Charge: ₹50.00
# Parking Duration: 1.33 minutes, Charge: ₹15.00
# Parking Duration: 0.74 minutes, Charge: ₹15.00
# Parking Duration: 126.00 minutes, Charge: ₹75.00
# Parking Duration: 43.78 minutes, Charge: ₹25.00
# Parking Duration: 48.69 minutes, Charge: ₹25.00
# Parking Duration: 18.54 minutes, Charge: ₹15.00
# Parking Duration: 118.70 minutes, Charge: ₹50.00
# Parking Duration: 46.58 minutes, Charge: ₹25.00
# Parking Duration: 85.16 minutes, Charge: ₹50.00
# Parking Duration: 35.80 minutes, Charge: ₹25.00
# Parking Duration: 0.88 minutes, Charge: ₹15.00
# Parking Duration: 24.43 minutes, Charge: ₹15.00
# Parking Duration: 9.59 minutes, Charge: ₹15.00
# Parking Duration: 40.90 minutes, Charge: ₹25.00
# Parking Duration: 99.04 minutes, Charge: ₹50.00
# Parking Duration: 23.26 minutes, Charge: ₹15.00
# Parking Duration: 90.01 minutes, Charge: ₹50.00
# Parking Duration: 34.10 minutes, Charge: ₹25.00
# Parking Duration: 155.62 minutes, Charge: ₹75.00
# Parking Duration: 0.71 minutes, Charge: ₹15.00
# Parking Duration: 11.09 minutes, Charge: ₹15.00
# Parking Duration: 19.95 minutes, Charge: ₹15.00
# Parking Duration: 75.65 minutes, Charge: ₹50.00
# Parking Duration: 244.04 minutes, Charge: ₹125.00
# Parking Duration: 17.02 minutes, Charge: ₹15.00
# Parking Duration: 206.49 minutes, Charge: ₹100.00
# Parking Duration: 51.12 minutes, Charge: ₹25.00
# Parking Duration: 47.37 minutes, Charge: ₹25.00
# Parking Duration: 73.57 minutes, Charge: ₹50.00
# Parking Duration: 43.60 minutes, Charge: ₹25.00
# Parking Duration: 156.86 minutes, Charge: ₹75.00
# Parking Duration: 47.47 minutes, Charge: ₹25.00
# Parking Duration: 56.93 minutes, Charge: ₹25.00
# Parking Duration: 18.97 minutes, Charge: ₹15.00
# Parking Duration: 11.02 minutes, Charge: ₹15.00
# Parking Duration: 15.72 minutes, Charge: ₹15.00
# Parking Duration: 18.21 minutes, Charge: ₹15.00
# Parking Duration: 3.23 minutes, Charge: ₹15.00
# Parking Duration: 81.31 minutes, Charge: ₹50.00
# Parking Duration: 39.90 minutes, Charge: ₹25.00
# Parking Duration: 13.29 minutes, Charge: ₹15.00
# Parking Duration: 6.79 minutes, Charge: ₹15.00
# Parking Duration: 18.00 minutes, Charge: ₹15.00
# Parking Duration: 7.75 minutes, Charge: ₹15.00
# Parking Duration: 70.16 minutes, Charge: ₹50.00
# Parking Duration: 44.50 minutes, Charge: ₹25.00
# Parking Duration: 25.91 minutes, Charge: ₹15.00
# Parking Duration: 4.81 minutes, Charge: ₹15.00
# Parking Duration: 2.85 minutes, Charge: ₹15.00
# Parking Duration: 8.69 minutes, Charge: ₹15.00
# Parking Duration: 43.46 minutes, Charge: ₹25.00
# Parking Duration: 20.24 minutes, Charge: ₹15.00
# Parking Duration: 0.89 minutes, Charge: ₹15.00
# Parking Duration: 61.64 minutes, Charge: ₹50.00
# Parking Duration: 48.11 minutes, Charge: ₹25.00
# Parking Duration: 504.68 minutes, Charge: ₹225.00
# Parking Duration: 15.74 minutes, Charge: ₹15.00
# Parking Duration: 98.93 minutes, Charge: ₹50.00
# Parking Duration: 12.13 minutes, Charge: ₹15.00
# Parking Duration: 14.47 minutes, Charge: ₹15.00
# Parking Duration: 34.53 minutes, Charge: ₹25.00
# Parking Duration: 50.58 minutes, Charge: ₹25.00
# Parking Duration: 60.20 minutes, Charge: ₹50.00
# Parking Duration: 45.99 minutes, Charge: ₹25.00
# Parking Duration: 14.76 minutes, Charge: ₹15.00
# Parking Duration: 32.10 minutes, Charge: ₹25.00
# Parking Duration: 197.81 minutes, Charge: ₹100.00
# Parking Duration: 12.93 minutes, Charge: ₹15.00
# Parking Duration: 69.31 minutes, Charge: ₹50.00
# Parking Duration: 34.38 minutes, Charge: ₹25.00
# Parking Duration: 53.50 minutes, Charge: ₹25.00
# Parking Duration: 106.13 minutes, Charge: ₹50.00
# Parking Duration: 38.09 minutes, Charge: ₹25.00
# Parking Duration: 52.73 minutes, Charge: ₹25.00
# Parking Duration: 16.37 minutes, Charge: ₹15.00
# Parking Duration: 2.03 minutes, Charge: ₹15.00
# Parking Duration: 50.57 minutes, Charge: ₹25.00
# Parking Duration: 21.35 minutes, Charge: ₹15.00
# Parking Duration: 43.80 minutes, Charge: ₹25.00
# Parking Duration: 51.79 minutes, Charge: ₹25.00
# Parking Duration: 27.94 minutes, Charge: ₹15.00
# Parking Duration: 70.42 minutes, Charge: ₹50.00
# Parking Duration: 2.52 minutes, Charge: ₹15.00
# Parking Duration: 94.53 minutes, Charge: ₹50.00
# Parking Duration: 293.26 minutes, Charge: ₹125.00
# Parking Duration: 26.76 minutes, Charge: ₹15.00
# Parking Duration: 5.77 minutes, Charge: ₹15.00
# Parking Duration: 39.09 minutes, Charge: ₹25.00
# Parking Duration: 163.66 minutes, Charge: ₹75.00
# Parking Duration: 88.95 minutes, Charge: ₹50.00
# Parking Duration: 6.56 minutes, Charge: ₹15.00
# Parking Duration: 308.94 minutes, Charge: ₹150.00
# Parking Duration: 24.08 minutes, Charge: ₹15.00
# Parking Duration: 38.29 minutes, Charge: ₹25.00
# Parking Duration: 185.35 minutes, Charge: ₹100.00
# Parking Duration: 115.91 minutes, Charge: ₹50.00
# Parking Duration: 14.00 minutes, Charge: ₹15.00
# Parking Duration: 43.86 minutes, Charge: ₹25.00
# Parking Duration: 45.31 minutes, Charge: ₹25.00
# Parking Duration: 14.44 minutes, Charge: ₹15.00
# Parking Duration: 0.71 minutes, Charge: ₹15.00
# Parking Duration: 21.52 minutes, Charge: ₹15.00
# Parking Duration: 20.72 minutes, Charge: ₹15.00
# Parking Duration: 21.12 minutes, Charge: ₹15.00
# Parking Duration: 10.65 minutes, Charge: ₹15.00
# Parking Duration: 103.11 minutes, Charge: ₹50.00
# Parking Duration: 17.70 minutes, Charge: ₹15.00
# Parking Duration: 216.98 minutes, Charge: ₹100.00
# Parking Duration: 84.00 minutes, Charge: ₹50.00
# Parking Duration: 34.53 minutes, Charge: ₹25.00
# Parking Duration: 44.92 minutes, Charge: ₹25.00
# Parking Duration: 31.00 minutes, Charge: ₹25.00
# Parking Duration: 32.35 minutes, Charge: ₹25.00
# Parking Duration: 97.20 minutes, Charge: ₹50.00
# Parking Duration: 3.73 minutes, Charge: ₹15.00
# Parking Duration: 11.15 minutes, Charge: ₹15.00
# Parking Duration: 96.34 minutes, Charge: ₹50.00
# Parking Duration: 26.47 minutes, Charge: ₹15.00
# Parking Duration: 58.10 minutes, Charge: ₹25.00
# Parking Duration: 131.86 minutes, Charge: ₹75.00
# Parking Duration: 36.47 minutes, Charge: ₹25.00
# Parking Duration: 63.15 minutes, Charge: ₹50.00
# Parking Duration: 36.30 minutes, Charge: ₹25.00
# Parking Duration: 17.94 minutes, Charge: ₹15.00
# Parking Duration: 34.99 minutes, Charge: ₹25.00
# Parking Duration: 6.60 minutes, Charge: ₹15.00
# Parking Duration: 59.98 minutes, Charge: ₹25.00
# Parking Duration: 11.87 minutes, Charge: ₹15.00
# Parking Duration: 43.22 minutes, Charge: ₹25.00
# Parking Duration: 35.48 minutes, Charge: ₹25.00
# Parking Duration: 40.59 minutes, Charge: ₹25.00
# Parking Duration: 29.65 minutes, Charge: ₹15.00
# Parking Duration: 2.14 minutes, Charge: ₹15.00
# Parking Duration: 57.47 minutes, Charge: ₹25.00
# Parking Duration: 59.54 minutes, Charge: ₹25.00
# Parking Duration: 13.23 minutes, Charge: ₹15.00
# Parking Duration: 34.82 minutes, Charge: ₹25.00
# Parking Duration: 34.41 minutes, Charge: ₹25.00
# Parking Duration: 105.73 minutes, Charge: ₹50.00
# Parking Duration: 19.83 minutes, Charge: ₹15.00
# Parking Duration: 84.14 minutes, Charge: ₹50.00
# Parking Duration: 32.11 minutes, Charge: ₹25.00
# Parking Duration: 43.88 minutes, Charge: ₹25.00
# Parking Duration: 77.03 minutes, Charge: ₹50.00
# Parking Duration: 32.28 minutes, Charge: ₹25.00
# Parking Duration: 16.11 minutes, Charge: ₹15.00
# Parking Duration: 111.42 minutes, Charge: ₹50.00
# Parking Duration: 89.14 minutes, Charge: ₹50.00
# Parking Duration: 18.27 minutes, Charge: ₹15.00
# Parking Duration: 49.67 minutes, Charge: ₹25.00
# Parking Duration: 28.46 minutes, Charge: ₹15.00
# Parking Duration: 72.35 minutes, Charge: ₹50.00
# Parking Duration: 190.11 minutes, Charge: ₹100.00
# Parking Duration: 89.14 minutes, Charge: ₹50.00
# Parking Duration: 93.23 minutes, Charge: ₹50.00
# Parking Duration: 9.25 minutes, Charge: ₹15.00
# Parking Duration: 30.70 minutes, Charge: ₹25.00
# Parking Duration: 329.87 minutes, Charge: ₹150.00
# Parking Duration: 61.71 minutes, Charge: ₹50.00
# Parking Duration: 67.27 minutes, Charge: ₹50.00
# Parking Duration: 67.63 minutes, Charge: ₹50.00
# Parking Duration: 21.74 minutes, Charge: ₹15.00
# Parking Duration: 37.33 minutes, Charge: ₹25.00
# Parking Duration: 8.83 minutes, Charge: ₹15.00
# Parking Duration: 38.66 minutes, Charge: ₹25.00
# Parking Duration: 92.84 minutes, Charge: ₹50.00
# Parking Duration: 142.09 minutes, Charge: ₹75.00
# Parking Duration: 21.70 minutes, Charge: ₹15.00
# Parking Duration: 41.20 minutes, Charge: ₹25.00
# Parking Duration: 81.12 minutes, Charge: ₹50.00
# Parking Duration: 27.23 minutes, Charge: ₹15.00
# Parking Duration: 12.08 minutes, Charge: ₹15.00
# Parking Duration: 54.72 minutes, Charge: ₹25.00
# Parking Duration: 71.67 minutes, Charge: ₹50.00
# Parking Duration: 76.58 minutes, Charge: ₹50.00
# Parking Duration: 33.75 minutes, Charge: ₹25.00
# Parking Duration: 48.39 minutes, Charge: ₹25.00
# Parking Duration: 408.05 minutes, Charge: ₹175.00
# Parking Duration: 50.67 minutes, Charge: ₹25.00
# Parking Duration: 7.25 minutes, Charge: ₹15.00
# Parking Duration: 45.21 minutes, Charge: ₹25.00
# Parking Duration: 165.38 minutes, Charge: ₹75.00
# Parking Duration: 31.33 minutes, Charge: ₹25.00
# Parking Duration: 1.81 minutes, Charge: ₹15.00
# Parking Duration: 41.70 minutes, Charge: ₹25.00
# Parking Duration: 3.70 minutes, Charge: ₹15.00
# Parking Duration: 10.74 minutes, Charge: ₹15.00
# Parking Duration: 2.76 minutes, Charge: ₹15.00
# Parking Duration: 8.24 minutes, Charge: ₹15.00
# Parking Duration: 92.80 minutes, Charge: ₹50.00
# Parking Duration: 30.26 minutes, Charge: ₹25.00
# Parking Duration: 188.28 minutes, Charge: ₹100.00
# Parking Duration: 28.31 minutes, Charge: ₹15.00
# Parking Duration: 31.62 minutes, Charge: ₹25.00
# Parking Duration: 54.60 minutes, Charge: ₹25.00
# Parking Duration: 9.90 minutes, Charge: ₹15.00
# Parking Duration: 41.02 minutes, Charge: ₹25.00
# Parking Duration: 129.55 minutes, Charge: ₹75.00
# Parking Duration: 133.86 minutes, Charge: ₹75.00
# Parking Duration: 195.49 minutes, Charge: ₹100.00
# Parking Duration: 47.46 minutes, Charge: ₹25.00
# Parking Duration: 52.69 minutes, Charge: ₹25.00
# Parking Duration: 49.23 minutes, Charge: ₹25.00
# Parking Duration: 67.57 minutes, Charge: ₹50.00
# Parking Duration: 0.87 minutes, Charge: ₹15.00
# Parking Duration: 235.41 minutes, Charge: ₹100.00
# Parking Duration: 37.26 minutes, Charge: ₹25.00
# Parking Duration: 15.88 minutes, Charge: ₹15.00
# Parking Duration: 38.18 minutes, Charge: ₹25.00
# Parking Duration: 155.22 minutes, Charge: ₹75.00
# Parking Duration: 86.93 minutes, Charge: ₹50.00
# Parking Duration: 81.47 minutes, Charge: ₹50.00
# Parking Duration: 19.97 minutes, Charge: ₹15.00
# Parking Duration: 58.60 minutes, Charge: ₹25.00
# Parking Duration: 128.14 minutes, Charge: ₹75.00
# Parking Duration: 35.55 minutes, Charge: ₹25.00
# Parking Duration: 24.36 minutes, Charge: ₹15.00
# Parking Duration: 71.89 minutes, Charge: ₹50.00
# Parking Duration: 94.97 minutes, Charge: ₹50.00
# Parking Duration: 18.94 minutes, Charge: ₹15.00
# Parking Duration: 11.03 minutes, Charge: ₹15.00
# Parking Duration: 34.04 minutes, Charge: ₹25.00
# Parking Duration: 98.65 minutes, Charge: ₹50.00
# Parking Duration: 49.76 minutes, Charge: ₹25.00
# Parking Duration: 169.90 minutes, Charge: ₹75.00
# Parking Duration: 7.04 minutes, Charge: ₹15.00
# Parking Duration: 6.96 minutes, Charge: ₹15.00
# Parking Duration: 206.47 minutes, Charge: ₹100.00
# Parking Duration: 154.57 minutes, Charge: ₹75.00
# Parking Duration: 17.92 minutes, Charge: ₹15.00
# Parking Duration: 155.95 minutes, Charge: ₹75.00
# Parking Duration: 95.50 minutes, Charge: ₹50.00
# Parking Duration: 0.03 minutes, Charge: ₹15.00
# Parking Duration: 19.17 minutes, Charge: ₹15.00
# Parking Duration: 44.94 minutes, Charge: ₹25.00
# Parking Duration: 15.80 minutes, Charge: ₹15.00
# Parking Duration: 113.18 minutes, Charge: ₹50.00
# Parking Duration: 22.22 minutes, Charge: ₹15.00
# Parking Duration: 71.51 minutes, Charge: ₹50.00
# Parking Duration: 44.53 minutes, Charge: ₹25.00
# Parking Duration: 88.40 minutes, Charge: ₹50.00
# Parking Duration: 183.27 minutes, Charge: ₹100.00
# Parking Duration: 25.60 minutes, Charge: ₹15.00
# Parking Duration: 93.29 minutes, Charge: ₹50.00
# Parking Duration: 41.22 minutes, Charge: ₹25.00
# Parking Duration: 57.64 minutes, Charge: ₹25.00
# Parking Duration: 96.29 minutes, Charge: ₹50.00
# Parking Duration: 7.07 minutes, Charge: ₹15.00
# Parking Duration: 145.99 minutes, Charge: ₹75.00
# Parking Duration: 31.78 minutes, Charge: ₹25.00
# Parking Duration: 94.11 minutes, Charge: ₹50.00
# Parking Duration: 59.18 minutes, Charge: ₹25.00
# Parking Duration: 44.42 minutes, Charge: ₹25.00
# Parking Duration: 150.34 minutes, Charge: ₹75.00
# Parking Duration: 66.56 minutes, Charge: ₹50.00
# Parking Duration: 8.43 minutes, Charge: ₹15.00
# Parking Duration: 54.41 minutes, Charge: ₹25.00
# Parking Duration: 110.05 minutes, Charge: ₹50.00
# Parking Duration: 98.41 minutes, Charge: ₹50.00
# Parking Duration: 100.71 minutes, Charge: ₹50.00
# Parking Duration: 46.65 minutes, Charge: ₹25.00
# Parking Duration: 104.62 minutes, Charge: ₹50.00
# Parking Duration: 63.65 minutes, Charge: ₹50.00
# Parking Duration: 185.33 minutes, Charge: ₹100.00
# Parking Duration: 12.10 minutes, Charge: ₹15.00
# Parking Duration: 1.92 minutes, Charge: ₹15.00
# Parking Duration: 35.30 minutes, Charge: ₹25.00
# Parking Duration: 11.86 minutes, Charge: ₹15.00
# Parking Duration: 31.71 minutes, Charge: ₹25.00
# Parking Duration: 91.46 minutes, Charge: ₹50.00
# Parking Duration: 12.49 minutes, Charge: ₹15.00
# Parking Duration: 83.81 minutes, Charge: ₹50.00
# Parking Duration: 29.61 minutes, Charge: ₹15.00
# Parking Duration: 1.99 minutes, Charge: ₹15.00
# Parking Duration: 25.95 minutes, Charge: ₹15.00
# Parking Duration: 90.42 minutes, Charge: ₹50.00
# Parking Duration: 28.03 minutes, Charge: ₹15.00
# Parking Duration: 8.62 minutes, Charge: ₹15.00
# Parking Duration: 57.00 minutes, Charge: ₹25.00
# Parking Duration: 23.77 minutes, Charge: ₹15.00
# Parking Duration: 39.42 minutes, Charge: ₹25.00
# Parking Duration: 47.67 minutes, Charge: ₹25.00
# Parking Duration: 41.21 minutes, Charge: ₹25.00
# Parking Duration: 7.52 minutes, Charge: ₹15.00
# Parking Duration: 17.04 minutes, Charge: ₹15.00
# Parking Duration: 72.18 minutes, Charge: ₹50.00
# Parking Duration: 68.52 minutes, Charge: ₹50.00
# Parking Duration: 40.64 minutes, Charge: ₹25.00
# Parking Duration: 129.77 minutes, Charge: ₹75.00
# Parking Duration: 44.06 minutes, Charge: ₹25.00
# Parking Duration: 8.98 minutes, Charge: ₹15.00
# Parking Duration: 27.11 minutes, Charge: ₹15.00
# Parking Duration: 172.03 minutes, Charge: ₹75.00
# Parking Duration: 3.08 minutes, Charge: ₹15.00
# Parking Duration: 25.92 minutes, Charge: ₹15.00
# Parking Duration: 28.82 minutes, Charge: ₹15.00
# Parking Duration: 29.17 minutes, Charge: ₹15.00
# Parking Duration: 71.42 minutes, Charge: ₹50.00
# Parking Duration: 208.14 minutes, Charge: ₹100.00
# Parking Duration: 7.43 minutes, Charge: ₹15.00
# Parking Duration: 15.60 minutes, Charge: ₹15.00
# Parking Duration: 19.28 minutes, Charge: ₹15.00
# Parking Duration: 10.96 minutes, Charge: ₹15.00
# Parking Duration: 26.28 minutes, Charge: ₹15.00
# Parking Duration: 35.84 minutes, Charge: ₹25.00
# Parking Duration: 125.06 minutes, Charge: ₹75.00
# Parking Duration: 61.72 minutes, Charge: ₹50.00
# Parking Duration: 327.50 minutes, Charge: ₹150.00
# Parking Duration: 63.86 minutes, Charge: ₹50.00
# Parking Duration: 126.07 minutes, Charge: ₹75.00
# Parking Duration: 10.38 minutes, Charge: ₹15.00
# Parking Duration: 109.76 minutes, Charge: ₹50.00
# Parking Duration: 1.95 minutes, Charge: ₹15.00
# Parking Duration: 16.82 minutes, Charge: ₹15.00
# Parking Duration: 42.22 minutes, Charge: ₹25.00
# Parking Duration: 117.08 minutes, Charge: ₹50.00
# Parking Duration: 74.73 minutes, Charge: ₹50.00
# Parking Duration: 27.98 minutes, Charge: ₹15.00
# Parking Duration: 6.99 minutes, Charge: ₹15.00
# Parking Duration: 88.82 minutes, Charge: ₹50.00
# Parking Duration: 41.41 minutes, Charge: ₹25.00
# Parking Duration: 76.16 minutes, Charge: ₹50.00
# Parking Duration: 49.69 minutes, Charge: ₹25.00
# Parking Duration: 0.34 minutes, Charge: ₹15.00
# Parking Duration: 17.80 minutes, Charge: ₹15.00
# Parking Duration: 13.26 minutes, Charge: ₹15.00
# Parking Duration: 57.05 minutes, Charge: ₹25.00
# Parking Duration: 15.31 minutes, Charge: ₹15.00
# Parking Duration: 93.49 minutes, Charge: ₹50.00
# Parking Duration: 123.68 minutes, Charge: ₹75.00
# Parking Duration: 25.32 minutes, Charge: ₹15.00
# Parking Duration: 8.97 minutes, Charge: ₹15.00
# Parking Duration: 16.06 minutes, Charge: ₹15.00
# Parking Duration: 15.12 minutes, Charge: ₹15.00
# Parking Duration: 50.79 minutes, Charge: ₹25.00
# Parking Duration: 13.17 minutes, Charge: ₹15.00
# Parking Duration: 41.30 minutes, Charge: ₹25.00
# Parking Duration: 51.69 minutes, Charge: ₹25.00
# Parking Duration: 11.47 minutes, Charge: ₹15.00
# Parking Duration: 3.31 minutes, Charge: ₹15.00
# Parking Duration: 136.02 minutes, Charge: ₹75.00
# Parking Duration: 57.92 minutes, Charge: ₹25.00
# Parking Duration: 69.56 minutes, Charge: ₹50.00
# Parking Duration: 11.93 minutes, Charge: ₹15.00
# Parking Duration: 66.75 minutes, Charge: ₹50.00
# Parking Duration: 22.74 minutes, Charge: ₹15.00
# Parking Duration: 43.89 minutes, Charge: ₹25.00
# Parking Duration: 204.34 minutes, Charge: ₹100.00
# Parking Duration: 71.56 minutes, Charge: ₹50.00
# Parking Duration: 77.19 minutes, Charge: ₹50.00
# Parking Duration: 9.46 minutes, Charge: ₹15.00
# Parking Duration: 36.43 minutes, Charge: ₹25.00
# Parking Duration: 34.46 minutes, Charge: ₹25.00
# Parking Duration: 140.02 minutes, Charge: ₹75.00
# Parking Duration: 116.35 minutes, Charge: ₹50.00
# Parking Duration: 34.66 minutes, Charge: ₹25.00
# Parking Duration: 64.33 minutes, Charge: ₹50.00
# Parking Duration: 100.32 minutes, Charge: ₹50.00
# Parking Duration: 19.75 minutes, Charge: ₹15.00
# Parking Duration: 29.44 minutes, Charge: ₹15.00
# Parking Duration: 177.25 minutes, Charge: ₹75.00
# Parking Duration: 31.11 minutes, Charge: ₹25.00
# Parking Duration: 113.94 minutes, Charge: ₹50.00
# Parking Duration: 15.65 minutes, Charge: ₹15.00
# Parking Duration: 28.05 minutes, Charge: ₹15.00
# Parking Duration: 91.72 minutes, Charge: ₹50.00
# Parking Duration: 16.32 minutes, Charge: ₹15.00
# Parking Duration: 153.19 minutes, Charge: ₹75.00
# Parking Duration: 15.59 minutes, Charge: ₹15.00
# Parking Duration: 70.82 minutes, Charge: ₹50.00
# Parking Duration: 65.87 minutes, Charge: ₹50.00
# Parking Duration: 5.45 minutes, Charge: ₹15.00
# Parking Duration: 128.48 minutes, Charge: ₹75.00
# Parking Duration: 7.24 minutes, Charge: ₹15.00
# Parking Duration: 18.09 minutes, Charge: ₹15.00
# Parking Duration: 11.61 minutes, Charge: ₹15.00
# Parking Duration: 53.36 minutes, Charge: ₹25.00
# Parking Duration: 188.38 minutes, Charge: ₹100.00
# Parking Duration: 104.26 minutes, Charge: ₹50.00
# Parking Duration: 29.60 minutes, Charge: ₹15.00
# Parking Duration: 3.93 minutes, Charge: ₹15.00
# Parking Duration: 47.73 minutes, Charge: ₹25.00
# Parking Duration: 20.03 minutes, Charge: ₹15.00
# Parking Duration: 5.56 minutes, Charge: ₹15.00
# Parking Duration: 3.20 minutes, Charge: ₹15.00
# Parking Duration: 26.37 minutes, Charge: ₹15.00
# Parking Duration: 46.56 minutes, Charge: ₹25.00
# Parking Duration: 126.92 minutes, Charge: ₹75.00
# Parking Duration: 34.67 minutes, Charge: ₹25.00
# Parking Duration: 47.78 minutes, Charge: ₹25.00
# Parking Duration: 14.82 minutes, Charge: ₹15.00
# Parking Duration: 9.35 minutes, Charge: ₹15.00
# Parking Duration: 0.60 minutes, Charge: ₹15.00
# Parking Duration: 105.86 minutes, Charge: ₹50.00
# Parking Duration: 45.88 minutes, Charge: ₹25.00
# Parking Duration: 121.99 minutes, Charge: ₹75.00
# Parking Duration: 59.30 minutes, Charge: ₹25.00
# Parking Duration: 23.72 minutes, Charge: ₹15.00
# Parking Duration: 1.63 minutes, Charge: ₹15.00
# Parking Duration: 46.41 minutes, Charge: ₹25.00
# Parking Duration: 8.90 minutes, Charge: ₹15.00
# Parking Duration: 21.06 minutes, Charge: ₹15.00
# Parking Duration: 4.05 minutes, Charge: ₹15.00
# Parking Duration: 2.31 minutes, Charge: ₹15.00
# Parking Duration: 72.86 minutes, Charge: ₹50.00
# Parking Duration: 55.75 minutes, Charge: ₹25.00
# Parking Duration: 68.13 minutes, Charge: ₹50.00
# Parking Duration: 31.87 minutes, Charge: ₹25.00
# Parking Duration: 58.96 minutes, Charge: ₹25.00
# Parking Duration: 13.80 minutes, Charge: ₹15.00
# Parking Duration: 19.71 minutes, Charge: ₹15.00
# Parking Duration: 26.89 minutes, Charge: ₹15.00
# Parking Duration: 19.13 minutes, Charge: ₹15.00
# Parking Duration: 104.11 minutes, Charge: ₹50.00
# Parking Duration: 283.67 minutes, Charge: ₹125.00
# Parking Duration: 26.61 minutes, Charge: ₹15.00
# Parking Duration: 142.49 minutes, Charge: ₹75.00
# Parking Duration: 1.48 minutes, Charge: ₹15.00
# Parking Duration: 8.09 minutes, Charge: ₹15.00
# Parking Duration: 60.16 minutes, Charge: ₹50.00
# Parking Duration: 15.07 minutes, Charge: ₹15.00
# Parking Duration: 63.24 minutes, Charge: ₹50.00
# Parking Duration: 101.31 minutes, Charge: ₹50.00
# Parking Duration: 19.87 minutes, Charge: ₹15.00
# Parking Duration: 40.02 minutes, Charge: ₹25.00
# Parking Duration: 1.35 minutes, Charge: ₹15.00
# Parking Duration: 89.49 minutes, Charge: ₹50.00
# Parking Duration: 34.63 minutes, Charge: ₹25.00
# Parking Duration: 32.59 minutes, Charge: ₹25.00
# Parking Duration: 18.50 minutes, Charge: ₹15.00
# Parking Duration: 158.09 minutes, Charge: ₹75.00
# Parking Duration: 89.60 minutes, Charge: ₹50.00
# Parking Duration: 47.44 minutes, Charge: ₹25.00
# Parking Duration: 8.75 minutes, Charge: ₹15.00
# Parking Duration: 6.72 minutes, Charge: ₹15.00
# Parking Duration: 21.29 minutes, Charge: ₹15.00
# Parking Duration: 121.63 minutes, Charge: ₹75.00
# Parking Duration: 28.73 minutes, Charge: ₹15.00
# Parking Duration: 148.60 minutes, Charge: ₹75.00
# Parking Duration: 80.46 minutes, Charge: ₹50.00
# Parking Duration: 48.12 minutes, Charge: ₹25.00
# Parking Duration: 95.27 minutes, Charge: ₹50.00
# Parking Duration: 53.66 minutes, Charge: ₹25.00
# Parking Duration: 13.99 minutes, Charge: ₹15.00
# Parking Duration: 34.59 minutes, Charge: ₹25.00
# Parking Duration: 11.67 minutes, Charge: ₹15.00
# Parking Duration: 9.52 minutes, Charge: ₹15.00
# Parking Duration: 5.75 minutes, Charge: ₹15.00
# Parking Duration: 7.13 minutes, Charge: ₹15.00
# Parking Duration: 133.11 minutes, Charge: ₹75.00
# Parking Duration: 83.90 minutes, Charge: ₹50.00
# Parking Duration: 33.72 minutes, Charge: ₹25.00
# Parking Duration: 22.39 minutes, Charge: ₹15.00
# Parking Duration: 18.28 minutes, Charge: ₹15.00
# Parking Duration: 14.49 minutes, Charge: ₹15.00
# Parking Duration: 92.25 minutes, Charge: ₹50.00
# Parking Duration: 7.78 minutes, Charge: ₹15.00
# Parking Duration: 45.48 minutes, Charge: ₹25.00
# Parking Duration: 21.60 minutes, Charge: ₹15.00
# Parking Duration: 25.34 minutes, Charge: ₹15.00
# Parking Duration: 5.41 minutes, Charge: ₹15.00
# Parking Duration: 38.65 minutes, Charge: ₹25.00
# Parking Duration: 16.72 minutes, Charge: ₹15.00
# Parking Duration: 82.47 minutes, Charge: ₹50.00
# Parking Duration: 135.19 minutes, Charge: ₹75.00
# Parking Duration: 11.74 minutes, Charge: ₹15.00
# Parking Duration: 40.13 minutes, Charge: ₹25.00
# Parking Duration: 30.02 minutes, Charge: ₹25.00
# Parking Duration: 79.74 minutes, Charge: ₹50.00
# Parking Duration: 5.97 minutes, Charge: ₹15.00
# Parking Duration: 52.94 minutes, Charge: ₹25.00
# Parking Duration: 41.88 minutes, Charge: ₹25.00
# Parking Duration: 68.43 minutes, Charge: ₹50.00
# Parking Duration: 13.90 minutes, Charge: ₹15.00
# Parking Duration: 231.00 minutes, Charge: ₹100.00
# Parking Duration: 7.92 minutes, Charge: ₹15.00
# Parking Duration: 135.67 minutes, Charge: ₹75.00
# Parking Duration: 26.22 minutes, Charge: ₹15.00
# Parking Duration: 117.96 minutes, Charge: ₹50.00
# Parking Duration: 9.79 minutes, Charge: ₹15.00
# Parking Duration: 15.85 minutes, Charge: ₹15.00
# Parking Duration: 10.89 minutes, Charge: ₹15.00
# Parking Duration: 162.00 minutes, Charge: ₹75.00
# Parking Duration: 25.44 minutes, Charge: ₹15.00
# Parking Duration: 46.35 minutes, Charge: ₹25.00
# Parking Duration: 154.79 minutes, Charge: ₹75.00
# Parking Duration: 79.82 minutes, Charge: ₹50.00
# Parking Duration: 4.70 minutes, Charge: ₹15.00
# Parking Duration: 13.39 minutes, Charge: ₹15.00
# Parking Duration: 41.85 minutes, Charge: ₹25.00
# Parking Duration: 27.52 minutes, Charge: ₹15.00
# Parking Duration: 1.64 minutes, Charge: ₹15.00
# Parking Duration: 62.27 minutes, Charge: ₹50.00
# Parking Duration: 21.08 minutes, Charge: ₹15.00
# Parking Duration: 73.87 minutes, Charge: ₹50.00
# Parking Duration: 94.77 minutes, Charge: ₹50.00
# Parking Duration: 76.35 minutes, Charge: ₹50.00
# Parking Duration: 12.12 minutes, Charge: ₹15.00
# Parking Duration: 69.26 minutes, Charge: ₹50.00
# Parking Duration: 132.99 minutes, Charge: ₹75.00
# Parking Duration: 181.63 minutes, Charge: ₹100.00
# Parking Duration: 90.89 minutes, Charge: ₹50.00
# Parking Duration: 51.48 minutes, Charge: ₹25.00
# Parking Duration: 30.49 minutes, Charge: ₹25.00
# Parking Duration: 87.62 minutes, Charge: ₹50.00
# Parking Duration: 65.22 minutes, Charge: ₹50.00
# Parking Duration: 63.45 minutes, Charge: ₹50.00
# Parking Duration: 122.49 minutes, Charge: ₹75.00
# Parking Duration: 45.25 minutes, Charge: ₹25.00
# Parking Duration: 59.51 minutes, Charge: ₹25.00
# Parking Duration: 34.62 minutes, Charge: ₹25.00
# Parking Duration: 56.57 minutes, Charge: ₹25.00
# Parking Duration: 8.61 minutes, Charge: ₹15.00
# Parking Duration: 87.23 minutes, Charge: ₹50.00
# Parking Duration: 41.75 minutes, Charge: ₹25.00
# Parking Duration: 10.53 minutes, Charge: ₹15.00
# Parking Duration: 40.95 minutes, Charge: ₹25.00
# Parking Duration: 16.25 minutes, Charge: ₹15.00
# Parking Duration: 50.93 minutes, Charge: ₹25.00
# Parking Duration: 39.42 minutes, Charge: ₹25.00
# Parking Duration: 183.40 minutes, Charge: ₹100.00
# Parking Duration: 142.60 minutes, Charge: ₹75.00
# Parking Duration: 108.21 minutes, Charge: ₹50.00
# Parking Duration: 133.26 minutes, Charge: ₹75.00
# Parking Duration: 82.42 minutes, Charge: ₹50.00
# Parking Duration: 30.84 minutes, Charge: ₹25.00
# Parking Duration: 28.12 minutes, Charge: ₹15.00
# Parking Duration: 0.11 minutes, Charge: ₹15.00
# Parking Duration: 9.43 minutes, Charge: ₹15.00
# Parking Duration: 156.98 minutes, Charge: ₹75.00
# Parking Duration: 23.55 minutes, Charge: ₹15.00
# Parking Duration: 53.00 minutes, Charge: ₹25.00
# Parking Duration: 42.86 minutes, Charge: ₹25.00
# Parking Duration: 31.36 minutes, Charge: ₹25.00
# Parking Duration: 9.44 minutes, Charge: ₹15.00
# Parking Duration: 17.04 minutes, Charge: ₹15.00
# Parking Duration: 47.68 minutes, Charge: ₹25.00
# Parking Duration: 15.68 minutes, Charge: ₹15.00
# Parking Duration: 56.14 minutes, Charge: ₹25.00
# Parking Duration: 75.81 minutes, Charge: ₹50.00
# Parking Duration: 0.96 minutes, Charge: ₹15.00
# Parking Duration: 78.01 minutes, Charge: ₹50.00
# Parking Duration: 12.18 minutes, Charge: ₹15.00
# Parking Duration: 65.91 minutes, Charge: ₹50.00
# Parking Duration: 22.72 minutes, Charge: ₹15.00
# Parking Duration: 27.02 minutes, Charge: ₹15.00
# Parking Duration: 0.59 minutes, Charge: ₹15.00
# Parking Duration: 82.43 minutes, Charge: ₹50.00
# Parking Duration: 91.65 minutes, Charge: ₹50.00
# Parking Duration: 70.87 minutes, Charge: ₹50.00
# Parking Duration: 34.28 minutes, Charge: ₹25.00
# Parking Duration: 11.40 minutes, Charge: ₹15.00
# Parking Duration: 30.46 minutes, Charge: ₹25.00
# Parking Duration: 28.51 minutes, Charge: ₹15.00
# Parking Duration: 39.88 minutes, Charge: ₹25.00
# Parking Duration: 24.21 minutes, Charge: ₹15.00
# Parking Duration: 29.00 minutes, Charge: ₹15.00
# ...
# Parking Duration: 132.79 minutes, Charge: ₹75.00
# Parking Duration: 11.37 minutes, Charge: ₹15.00
# Parking Duration: 74.20 minutes, Charge: ₹50.00
# Parking Duration: 157.55 minutes, Charge: ₹75.00
# Parking Duration: 27.84 minutes, Charge: ₹15.00
# Parking Duration: 353.55 minutes, Charge: ₹150.00
# Parking Duration: 80.29 minutes, Charge: ₹50.00
# Parking Duration: 28.90 minutes, Charge: ₹15.00
# Parking Duration: 64.13 minutes, Charge: ₹50.00
# Parking Duration: 25.36 minutes, Charge: ₹15.00
# Parking Duration: 66.74 minutes, Charge: ₹50.00
# Parking Duration: 25.02 minutes, Charge: ₹15.00
# Parking Duration: 16.19 minutes, Charge: ₹15.00
# Parking Duration: 124.35 minutes, Charge: ₹75.00
# Parking Duration: 224.70 minutes, Charge: ₹100.00
# Parking Duration: 56.03 minutes, Charge: ₹25.00
# Parking Duration: 10.65 minutes, Charge: ₹15.00
# Parking Duration: 16.45 minutes, Charge: ₹15.00
# Parking Duration: 33.14 minutes, Charge: ₹25.00
# Parking Duration: 37.86 minutes, Charge: ₹25.00
# Parking Duration: 56.27 minutes, Charge: ₹25.00
# Parking Duration: 66.44 minutes, Charge: ₹50.00
# Parking Duration: 108.25 minutes, Charge: ₹50.00
# Parking Duration: 82.89 minutes, Charge: ₹50.00
# Parking Duration: 0.55 minutes, Charge: ₹15.00
# Parking Duration: 6.41 minutes, Charge: ₹15.00
# Parking Duration: 48.19 minutes, Charge: ₹25.00
# Parking Duration: 12.93 minutes, Charge: ₹15.00
# Parking Duration: 40.17 minutes, Charge: ₹25.00
# Parking Duration: 19.58 minutes, Charge: ₹15.00
# Parking Duration: 53.40 minutes, Charge: ₹25.00
# Parking Duration: 5.58 minutes, Charge: ₹15.00
# Parking Duration: 132.93 minutes, Charge: ₹75.00
# Parking Duration: 76.31 minutes, Charge: ₹50.00
# Parking Duration: 3.08 minutes, Charge: ₹15.00
# Parking Duration: 60.21 minutes, Charge: ₹50.00
# Parking Duration: 39.09 minutes, Charge: ₹25.00
# Parking Duration: 7.91 minutes, Charge: ₹15.00
# Parking Duration: 200.82 minutes, Charge: ₹100.00
# Parking Duration: 95.12 minutes, Charge: ₹50.00
# Parking Duration: 311.14 minutes, Charge: ₹150.00
# Parking Duration: 19.94 minutes, Charge: ₹15.00
# Parking Duration: 318.28 minutes, Charge: ₹150.00
# Parking Duration: 59.78 minutes, Charge: ₹25.00
# Parking Duration: 32.41 minutes, Charge: ₹25.00
# Parking Duration: 22.88 minutes, Charge: ₹15.00
# Parking Duration: 54.57 minutes, Charge: ₹25.00
# Parking Duration: 56.61 minutes, Charge: ₹25.00
# Parking Duration: 29.67 minutes, Charge: ₹15.00
# Parking Duration: 0.46 minutes, Charge: ₹15.00
# Parking Duration: 81.59 minutes, Charge: ₹50.00
# Parking Duration: 67.99 minutes, Charge: ₹50.00
# Parking Duration: 75.24 minutes, Charge: ₹50.00
# Parking Duration: 107.51 minutes, Charge: ₹50.00
# Parking Duration: 39.96 minutes, Charge: ₹25.00
# Parking Duration: 80.76 minutes, Charge: ₹50.00
# Parking Duration: 25.86 minutes, Charge: ₹15.00
# Parking Duration: 11.81 minutes, Charge: ₹15.00
# Parking Duration: 37.22 minutes, Charge: ₹25.00
# Parking Duration: 33.89 minutes, Charge: ₹25.00
# Parking Duration: 82.07 minutes, Charge: ₹50.00
# Parking Duration: 145.31 minutes, Charge: ₹75.00
# Parking Duration: 16.98 minutes, Charge: ₹15.00
# Parking Duration: 35.93 minutes, Charge: ₹25.00
# Parking Duration: 21.85 minutes, Charge: ₹15.00
# Parking Duration: 146.70 minutes, Charge: ₹75.00
# Parking Duration: 45.37 minutes, Charge: ₹25.00
# Parking Duration: 70.81 minutes, Charge: ₹50.00
# Parking Duration: 2.89 minutes, Charge: ₹15.00
# Parking Duration: 20.30 minutes, Charge: ₹15.00
# Parking Duration: 132.49 minutes, Charge: ₹75.00
# Parking Duration: 8.09 minutes, Charge: ₹15.00
# Parking Duration: 16.61 minutes, Charge: ₹15.00
# Parking Duration: 26.59 minutes, Charge: ₹15.00
# Parking Duration: 48.59 minutes, Charge: ₹25.00
# Parking Duration: 5.92 minutes, Charge: ₹15.00
# Parking Duration: 71.73 minutes, Charge: ₹50.00
# Parking Duration: 8.32 minutes, Charge: ₹15.00
# Parking Duration: 18.60 minutes, Charge: ₹15.00
# Parking Duration: 4.43 minutes, Charge: ₹15.00
# Parking Duration: 7.47 minutes, Charge: ₹15.00
# Parking Duration: 2.29 minutes, Charge: ₹15.00
# Parking Duration: 221.24 minutes, Charge: ₹100.00
# Parking Duration: 70.28 minutes, Charge: ₹50.00
# Parking Duration: 1.01 minutes, Charge: ₹15.00
# Parking Duration: 17.22 minutes, Charge: ₹15.00
# Parking Duration: 0.05 minutes, Charge: ₹15.00
# Parking Duration: 48.96 minutes, Charge: ₹25.00
# Parking Duration: 47.23 minutes, Charge: ₹25.00
# Parking Duration: 34.85 minutes, Charge: ₹25.00
# Parking Duration: 33.81 minutes, Charge: ₹25.00
# Parking Duration: 4.75 minutes, Charge: ₹15.00
# Parking Duration: 28.54 minutes, Charge: ₹15.00
# Parking Duration: 155.58 minutes, Charge: ₹75.00
# Parking Duration: 111.75 minutes, Charge: ₹50.00
# Parking Duration: 33.08 minutes, Charge: ₹25.00
# Parking Duration: 86.59 minutes, Charge: ₹50.00
# Parking Duration: 71.98 minutes, Charge: ₹50.00
# Parking Duration: 8.44 minutes, Charge: ₹15.00
# Parking Duration: 55.23 minutes, Charge: ₹25.00
# Parking Duration: 55.27 minutes, Charge: ₹25.00
# Parking Duration: 16.64 minutes, Charge: ₹15.00
# Parking Duration: 2.33 minutes, Charge: ₹15.00
# Parking Duration: 73.88 minutes, Charge: ₹50.00
# Parking Duration: 90.80 minutes, Charge: ₹50.00
# Parking Duration: 19.70 minutes, Charge: ₹15.00
# Parking Duration: 43.63 minutes, Charge: ₹25.00
# Parking Duration: 33.12 minutes, Charge: ₹25.00
# Parking Duration: 176.22 minutes, Charge: ₹75.00
# Parking Duration: 38.59 minutes, Charge: ₹25.00
# Parking Duration: 234.65 minutes, Charge: ₹100.00
# Parking Duration: 44.27 minutes, Charge: ₹25.00
# Parking Duration: 2.62 minutes, Charge: ₹15.00
# Parking Duration: 17.60 minutes, Charge: ₹15.00
# Parking Duration: 42.12 minutes, Charge: ₹25.00
# Parking Duration: 61.75 minutes, Charge: ₹50.00
# Parking Duration: 7.03 minutes, Charge: ₹15.00
# Parking Duration: 201.82 minutes, Charge: ₹100.00
# Parking Duration: 1.32 minutes, Charge: ₹15.00
# Parking Duration: 14.88 minutes, Charge: ₹15.00
# Parking Duration: 131.20 minutes, Charge: ₹75.00
# Parking Duration: 13.27 minutes, Charge: ₹15.00
# Parking Duration: 45.92 minutes, Charge: ₹25.00
# Parking Duration: 106.22 minutes, Charge: ₹50.00
# Parking Duration: 116.21 minutes, Charge: ₹50.00
# Parking Duration: 82.01 minutes, Charge: ₹50.00
# Parking Duration: 44.62 minutes, Charge: ₹25.00
# Parking Duration: 16.60 minutes, Charge: ₹15.00
# Parking Duration: 34.46 minutes, Charge: ₹25.00
# Parking Duration: 114.35 minutes, Charge: ₹50.00
# Parking Duration: 130.50 minutes, Charge: ₹75.00
# Parking Duration: 74.51 minutes, Charge: ₹50.00
# Parking Duration: 206.67 minutes, Charge: ₹100.00
# Parking Duration: 58.17 minutes, Charge: ₹25.00
# Parking Duration: 38.97 minutes, Charge: ₹25.00
# Parking Duration: 40.32 minutes, Charge: ₹25.00
# Parking Duration: 17.63 minutes, Charge: ₹15.00
# Parking Duration: 20.13 minutes, Charge: ₹15.00
# Parking Duration: 36.20 minutes, Charge: ₹25.00
# Parking Duration: 60.25 minutes, Charge: ₹50.00
# Parking Duration: 9.40 minutes, Charge: ₹15.00
# Parking Duration: 158.13 minutes, Charge: ₹75.00
# Parking Duration: 30.47 minutes, Charge: ₹25.00
# Parking Duration: 151.67 minutes, Charge: ₹75.00
# Parking Duration: 61.70 minutes, Charge: ₹50.00
# Parking Duration: 22.68 minutes, Charge: ₹15.00
# Parking Duration: 20.20 minutes, Charge: ₹15.00
# Parking Duration: 110.21 minutes, Charge: ₹50.00
# Parking Duration: 68.35 minutes, Charge: ₹50.00
# Parking Duration: 49.89 minutes, Charge: ₹25.00
# Parking Duration: 62.15 minutes, Charge: ₹50.00
# Parking Duration: 54.36 minutes, Charge: ₹25.00
# Parking Duration: 49.23 minutes, Charge: ₹25.00
# Parking Duration: 50.68 minutes, Charge: ₹25.00
# Parking Duration: 39.05 minutes, Charge: ₹25.00
# Parking Duration: 5.39 minutes, Charge: ₹15.00
# Parking Duration: 2.92 minutes, Charge: ₹15.00
# Parking Duration: 20.74 minutes, Charge: ₹15.00
# Parking Duration: 12.03 minutes, Charge: ₹15.00
# Parking Duration: 126.95 minutes, Charge: ₹75.00
# Parking Duration: 148.60 minutes, Charge: ₹75.00
# Parking Duration: 54.07 minutes, Charge: ₹25.00
# Parking Duration: 30.09 minutes, Charge: ₹25.00
# Parking Duration: 124.06 minutes, Charge: ₹75.00
# Parking Duration: 88.85 minutes, Charge: ₹50.00
# Parking Duration: 13.63 minutes, Charge: ₹15.00
# Parking Duration: 165.77 minutes, Charge: ₹75.00
# Parking Duration: 20.42 minutes, Charge: ₹15.00
# Parking Duration: 19.78 minutes, Charge: ₹15.00
# Parking Arrival Pattern Over 30 Days:
#         8:00  9:00  10:00  11:00  12:00  13:00  14:00  15:00  16:00  17:00  \
# Day 1    7.0   7.0   15.0    4.0   33.0   44.0   34.0   29.0   33.0   36.0
# Day 2    8.0  14.0   11.0   20.0   30.0   46.0   35.0   33.0   52.0   48.0
# Day 3   13.0   7.0   13.0   10.0   37.0   36.0   40.0   49.0   48.0   52.0
# Day 4    5.0  10.0    7.0   11.0   45.0   35.0   42.0   45.0   34.0   35.0
# Day 5   21.0  13.0    6.0   10.0   26.0   45.0   35.0   45.0   57.0   48.0
# Day 6   16.0  16.0   19.0    6.0   51.0   57.0   63.0   74.0   61.0   60.0
# Day 7   22.0  15.0   15.0   17.0   51.0   63.0   67.0   57.0   54.0   63.0
# Day 8   11.0   9.0   14.0   12.0   36.0   45.0   40.0   43.0   43.0   36.0
# Day 9   10.0   7.0    9.0   16.0   46.0   42.0   42.0   48.0   41.0   38.0
# Day 10  13.0  12.0    8.0   15.0   29.0   41.0   51.0   44.0   38.0   34.0
# Day 11  11.0   9.0   11.0   14.0   30.0   40.0   43.0   37.0   35.0   49.0
# Day 12  11.0  12.0   10.0    7.0   28.0   37.0   38.0   39.0   32.0   43.0
# Day 13  15.0  16.0   17.0   20.0   55.0   55.0   54.0   63.0   50.0   65.0
# Day 14  12.0  15.0   22.0   12.0   53.0   56.0   53.0   51.0   54.0   53.0
# Day 15  12.0  19.0   14.0   13.0   32.0   47.0   50.0   53.0   45.0   35.0
# Day 16   8.0  17.0    7.0   10.0   39.0   46.0   36.0   43.0   40.0   38.0
# Day 17  13.0   9.0   20.0   21.0   40.0   43.0   36.0   30.0   56.0   38.0
# Day 18  13.0   8.0   11.0    6.0   31.0   37.0   52.0   48.0   39.0   42.0
# Day 19  15.0  13.0    7.0   11.0   51.0   53.0   39.0   32.0   29.0   31.0
# Day 20  16.0  21.0   10.0   22.0   60.0   58.0   52.0   53.0   58.0   75.0
# Day 21  18.0  28.0   11.0    5.0   47.0   49.0   76.0   42.0   69.0   77.0
# Day 22  13.0  19.0   16.0   14.0   30.0   37.0   39.0   39.0   46.0   35.0
# Day 23   7.0  10.0    7.0   15.0   44.0   41.0   43.0   37.0   40.0   31.0
# Day 24  10.0  10.0   13.0    4.0   56.0   36.0   37.0   41.0   24.0   36.0
# Day 25  12.0  10.0    7.0    8.0   38.0   33.0   32.0   30.0   31.0   35.0
# Day 26   9.0  10.0   11.0    8.0   30.0   31.0   28.0   45.0   49.0   40.0
# Day 27  26.0  22.0   14.0   16.0   63.0   63.0   55.0   50.0   55.0   67.0
# Day 28  18.0  18.0   16.0   15.0   66.0   61.0   43.0   64.0   56.0   69.0
# Day 29  12.0  15.0   12.0   11.0   26.0   36.0   44.0   29.0   32.0   39.0
# Day 30  13.0  12.0   11.0   13.0   27.0   47.0   37.0   39.0   33.0   35.0
#
#         18:00  19:00
# Day 1    39.0   43.0
# Day 2    42.0   39.0
# Day 3    40.0   36.0
# Day 4    30.0   31.0
# Day 5    27.0   36.0
# Day 6    55.0   66.0
# Day 7    56.0   70.0
# Day 8    48.0   48.0
# Day 9    42.0   40.0
# Day 10   43.0   47.0
# Day 11   50.0   41.0
# Day 12   33.0   35.0
# Day 13   65.0   64.0
# Day 14   52.0   52.0
# Day 15   42.0   48.0
# Day 16   37.0   44.0
# Day 17   38.0   31.0
# Day 18   39.0   32.0
# Day 19   45.0   36.0
# Day 20   66.0   58.0
# Day 21   67.0   59.0
# Day 22   36.0   45.0
# Day 23   36.0   32.0
# Day 24   52.0   31.0
# Day 25   36.0   45.0
# Day 26   31.0   39.0
# Day 27   69.0   64.0
# Day 28   54.0   60.0
# Day 29   32.0   40.0
# Day 30   30.0   12.0
#
# Average Inter-Arrival Time (in minutes) Over 30 Days:
#             8:00      9:00     10:00      11:00     12:00     13:00     14:00  \
# Day 1   8.941267  7.828187  4.721736   7.526370  1.546464  1.136056  1.291120
# Day 2   5.651741  3.960359  4.597989   2.987884  1.252232  1.177570  1.582480
# Day 3   4.366138  6.802665  4.179234   4.709799  1.114082  1.364106  1.114491
# Day 4   3.750369  5.366904  7.077193   3.091362  0.969158  1.267755  1.206350
# Day 5   2.770973  4.506707  8.707022   4.680894  1.465022  1.216472  1.277313
# Day 6   3.347147  2.525042  1.891624   7.159075  0.886505  0.881674  0.746052
# Day 7   2.553746  2.048549  3.352562   2.735485  0.779680  0.761754  0.788184
# Day 8   4.646974  4.795813  2.824442   4.437139  1.275914  1.057175  1.310914
# Day 9   5.579096  5.887031  4.846332   2.753388  1.080348  0.979384  1.153199
# Day 10  2.967632  4.406082  7.141272   3.205436  1.523025  1.169069  1.013063
# Day 11  5.159515  3.585875  3.036747   4.362611  1.327354  1.351204  1.157942
# Day 12  5.018197  4.255632  4.719602   6.041981  1.624008  1.392599  1.210719
# Day 13  2.715075  3.538399  3.412831   2.798587  0.763966  0.765643  0.770226
# Day 14  4.645148  3.430264  1.787623   3.991298  0.837984  0.767943  0.821744
# Day 15  3.323427  2.843589  4.061023   3.813284  1.472663  1.174356  1.008185
# Day 16  4.514111  3.175146  7.279324   4.950093  1.193948  0.981702  1.141601
# Day 17  2.321648  4.910141  2.458276   2.017044  1.113133  0.920959  1.257793
# Day 18  4.230040  7.308346  4.290711  10.118450  1.182373  1.130872  1.012001
# Day 19  2.561178  5.394658  5.957189   4.653002  1.009762  0.838047  1.164245
# Day 20  3.621158  2.605199  3.771710   2.507376  0.787333  0.794015  0.830546
# Day 21  3.022137  2.041689  3.363783   7.661079  0.879148  0.945630  0.680938
# Day 22  3.265939  2.783243  3.129824   4.094058  1.627815  1.250589  1.069377
# Day 23  7.610940  4.705685  8.060329   2.843077  1.179298  0.932173  1.148728
# Day 24  6.123910  4.730098  3.976873   2.860631  0.952059  1.274599  1.336334
# Day 25  4.256838  4.365605  5.306773   6.431900  0.962099  1.212067  1.469473
# Day 26  3.446657  5.302046  2.982423   7.298795  1.259312  1.758785  2.013909
# Day 27  2.160191  2.491215  2.521964   3.621663  0.792124  0.823346  0.899300
# Day 28  3.307616  2.644219  3.165499   2.944934  0.778349  0.825020  1.144613
# Day 29  5.214121  3.585282  4.118357   3.649162  1.766883  1.054371  1.073892
# Day 30  3.501489  4.303859  4.841767   5.196517  1.528285  0.942929  1.370253
#
#            15:00     16:00     17:00     18:00     19:00
# Day 1   1.521124  1.397910  1.320098  1.397720  1.109470
# Day 2   1.426331  0.889856  1.152088  1.307381  1.141231
# Day 3   1.011996  1.056282  1.042406  1.124365  1.114792
# Day 4   1.196756  1.262896  0.970368  1.604607  1.423303
# Day 5   1.161418  0.838203  0.953623  1.450214  1.104094
# Day 6   0.714883  0.815423  0.852195  0.939651  0.767996
# Day 7   0.904333  0.959199  0.697088  0.839007  0.653865
# Day 8   1.187986  1.153874  1.301744  0.992065  1.130083
# Day 9   1.047717  1.132636  1.154565  1.016161  1.087270
# Day 10  1.204748  1.425244  1.473697  1.278580  1.058894
# Day 11  1.270805  1.072817  0.958024  0.973729  1.270232
# Day 12  1.322265  1.447240  0.902684  1.346154  1.319809
# Day 13  0.764865  0.981312  0.811878  0.828240  0.695579
# Day 14  0.970739  0.915964  0.790546  0.794941  0.893433
# Day 15  0.974612  1.108979  1.559535  1.221348  1.014565
# Day 16  1.136709  1.083546  1.314644  1.491904  1.164314
# Day 17  1.200086  0.892338  1.297819  1.223930  1.621967
# Day 18  1.207970  1.359727  1.318544  1.135998  1.499032
# Day 19  1.324971  1.498439  1.667715  1.119552  1.433848
# Day 20  0.852440  0.955803  0.656409  0.705901  0.746135
# Day 21  1.032284  0.739697  0.649331  0.767922  0.703871
# Day 22  1.169842  1.066231  1.367853  1.151129  1.165202
# Day 23  1.423941  1.181789  1.755022  1.585346  1.791500
# Day 24  1.233070  1.594074  1.464245  0.869139  1.341017
# Day 25  1.601213  1.663890  1.495107  1.220870  1.020391
# Day 26  0.914558  1.025074  1.271697  1.670356  1.210526
# Day 27  0.880458  0.951723  0.724642  0.765284  0.754537
# Day 28  0.698539  0.835231  0.730739  0.784253  0.791345
# Day 29  1.589662  1.199383  1.016937  1.469119  1.110212
# Day 30  1.297384  1.283944  1.248873  1.246447  1.503105
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 7.81%
# 12-16:59: 14.98%
# 17-20:00: 17.97%
#
# Total Parked Customers: 12195
# Total Lost Customers: 3064
# Percentage of Lost Customers: 20.08%
# Total Revenue Over 30 Days: ₹430450.00
# Total Lost Revenue Due to Lost Customers: ₹45960.00
