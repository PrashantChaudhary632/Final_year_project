# %%
import simpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Simulation parameters
SIM_DURATION = 30 * 12 * 60  # 30 days, 12 hours per day (8 AM to 8 PM)
CAPACITY = 200
WILLINGNESS_TO_VISIT = 0.80  # 80% willingness to visit

# Arrival rates based on the day of the week and time slots
ARRIVAL_RATES = {
    'Sunday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Monday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Tuesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Wednesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Thursday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Friday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)],
    'Saturday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)]
}

# Initialize data for tracking arrivals, inter-arrival times, parking durations, revenue, and parking space utilization
arrival_pattern = np.zeros((30, 12))  # 30 days, 12 hours per day (8 AM to 8 PM)
inter_arrival_times = [[] for _ in range(30 * 12)]  # List of lists for storing inter-arrival times for each time slot
parking_durations = []  # List to store parking durations
total_revenue = 0  # Total revenue accumulator
lost_customers = 0  # Lost customers accumulator
parked_customers = 0  # Parked customers accumulator
utilization_data = []  # List to store occupancy data for utilization calculation

def get_arrival_rate(day, hour):
    """Return the arrival rate based on the day and hour."""
    for start, end, rate in ARRIVAL_RATES[day]:
        if start <= hour < end:
            return rate
    return 0

def calculate_charge(parking_duration):
    """Calculate the charge based on parking duration with ceiling logic."""
    if parking_duration < 30:
        return 15
    else:
        hours = np.ceil(parking_duration / 60)  # Round up to the nearest hour
        return 25 * hours  # Charge ₹25 per hour

def vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time):
    """Simulates vehicle parking behavior, tracks arrivals, inter-arrival times, and calculates revenue."""
    global total_revenue, lost_customers, parked_customers
    
    # Check if the vehicle decides to park based on willingness to visit
    if np.random.random() > WILLINGNESS_TO_VISIT:
        lost_customers += 1
        return  # Vehicle leaves without parking

    # Generate parking duration (in minutes)
    parking_duration = np.random.exponential(60)  # Exponential distribution with mean 60 minutes
    
    # Store parking duration
    parking_durations.append(parking_duration)
    
    # Calculate the charge based on parking duration
    charge = calculate_charge(parking_duration)
    
    # Print the charge for debugging
    print(f"Parking Duration: {parking_duration:.2f} minutes, Charge: ₹{charge:.2f}")
    
    # Update total revenue
    total_revenue += charge
    parked_customers += 1  # Increment parked customers counter
    
    with parking_lot.request() as request:
        yield request
        # Update occupancy data
        current_time = env.now
        num_vehicles = len(parking_lot.users)
        utilization_data.append((current_time, num_vehicles))
        yield env.timeout(parking_duration)
        # Track arrivals for the specific day and hour
        arrival_pattern[day_index, hour_index] += 1  # Use correct indexing for Numpy arrays
        # Store the inter-arrival time
        inter_arrival_times[day_index * 12 + hour_index].append(inter_arrival_time)

def arrival_process(env, parking_lot, day, day_index):
    """Simulates the arrival process based on the day and time."""
    global parked_customers, lost_customers
    while env.now < (day_index + 1) * 12 * 60:  # Simulate only 12 hours per day
        current_hour = (env.now // 60) % 12 + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
        rate = get_arrival_rate(day, current_hour)
        
        # Determine the hour index (0 to 11 for 8 AM to 8 PM)
        hour_index = int(current_hour - 8)  # Adjust index to match 0-11 range
        
        if 0 <= hour_index < 12:  # Ensure hour_index is within valid bounds
            if rate > 0:
                inter_arrival_time = np.random.exponential(60 / rate)  # Convert hourly rate to inter-arrival time
                yield env.timeout(inter_arrival_time)
                env.process(vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time))
            else:
                yield env.timeout(1)  # Wait for 1 minute if no arrival

def run_simulation():
    """Runs the simulation for 30 days."""
    global total_revenue, lost_customers, parked_customers
    env = simpy.Environment()
    parking_lot = simpy.Resource(env, capacity=CAPACITY)

    for day_index in range(30):
        day_name = list(ARRIVAL_RATES.keys())[day_index % 7]  # Cycle through days of the week
        env.process(arrival_process(env, parking_lot, day_name, day_index))

        # Simulate 12 hours of the current day
        env.run(until=(day_index + 1) * 12 * 60)

# Run the simulation
run_simulation()

# Calculate average inter-arrival time for each time slot
average_inter_arrival = np.zeros((30, 12))  # 30 days, 12 hours per day

for i in range(30):
    for j in range(12):
        if inter_arrival_times[i * 12 + j]:  # Check if there are any inter-arrival times recorded
            average_inter_arrival[i, j] = np.mean(inter_arrival_times[i * 12 + j])

# Create DataFrames for the heatmaps
hours = [f"{hour}:00" for hour in range(8, 20)]  # Hour labels from 8 AM to 8 PM
days = [f"Day {i+1}" for i in range(30)]
arrival_df = pd.DataFrame(arrival_pattern, index=days, columns=hours)
average_inter_arrival_df = pd.DataFrame(average_inter_arrival, index=days, columns=hours)

# Print arrival pattern, average inter-arrival time, total revenue, and time slot utilization
print("Parking Arrival Pattern Over 30 Days:")
print(arrival_df)
print("\nAverage Inter-Arrival Time (in minutes) Over 30 Days:")
print(average_inter_arrival_df)

# Calculate parking space utilization for each time slot
time_slot_utilization = {
    '8-11:59': [],
    '12-16:59': [],
    '17-20:00': []
}

# Utility function to get time slot based on the hour
def get_time_slot(hour):
    if 8 <= hour < 12:
        return '8-11:59'
    elif 12 <= hour < 17:
        return '12-16:59'
    elif 17 <= hour < 20:
        return '17-20:00'
    return None

# Compute the total occupied time based on occupancy data and categorize by time slots
previous_time = 0  # Reset previous_time before usage
for current_time, num_vehicles in utilization_data:
    hour = int((current_time // 60) % 12) + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
    time_slot = get_time_slot(hour)
    if time_slot:
        time_spent = current_time - previous_time
        time_slot_utilization[time_slot].append(time_spent * (num_vehicles / CAPACITY))
    previous_time = current_time

# Calculate average utilization for each time slot
total_time_per_slot = {
    '8-11:59': 4 * 60 * 30,  # 4 hours per day, 30 days
    '12-16:59': 5 * 60 * 30,  # 5 hours per day, 30 days
    '17-20:00': 3 * 60 * 30   # 3 hours per day, 30 days
}

average_utilization_by_slot = {
    slot: (np.sum(time_slot_utilization[slot]) / total_time_per_slot[slot]) * 100
    for slot in time_slot_utilization
}

# Print average parking space utilization by time slot
print("\nAverage Parking Space Utilization by Time Slot:")
for slot, utilization in average_utilization_by_slot.items():
    print(f"{slot}: {utilization:.2f}%")

# Calculate percentage of lost customers
total_attempted_arrivals = parked_customers + lost_customers
percentage_lost_customers = (lost_customers / total_attempted_arrivals) * 100 if total_attempted_arrivals > 0 else 0

# Print results
print(f"\nTotal Parked Customers: {parked_customers}")
print(f"Total Lost Customers: {lost_customers}")
print(f"Percentage of Lost Customers: {percentage_lost_customers:.2f}%")

# Plotting the heatmaps
plt.figure(figsize=(16, 12))

# Heatmap for parking arrival pattern
plt.subplot(1, 2, 1)
sns.heatmap(arrival_df, annot=True, cmap="YlGnBu", cbar=True, fmt=".0f")
plt.title("Parking Arrival Pattern Over 30 Days")
plt.xlabel("Hours")
plt.ylabel("Days")

# Heatmap for average inter-arrival time
plt.subplot(1, 2, 2)
sns.heatmap(average_inter_arrival_df, annot=True, cmap="YlGnBu", cbar=True, fmt=".1f")
plt.title("Average Inter-Arrival Time Over 30 Days")
plt.xlabel("Hours")
plt.ylabel("Days")

plt.tight_layout()
plt.show()

# Plot parking duration histogram
plt.figure(figsize=(12, 6))
max_duration = int(max(parking_durations))
bins = range(0, max_duration + 10, 20)  # Create bins with 10-minute intervals
plt.hist(parking_durations, bins=bins, edgecolor='black', linewidth=1.5)  # Increased linewidth

# Customizing x-ticks to show intervals of 10 minutes
plt.xticks(bins)

plt.title("Histogram of Parking Durations")
plt.xlabel("Parking Duration (minutes)")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.7)  # Add gridlines for better readability

plt.show()

# Calculate lost revenue
lost_revenue = lost_customers * 15  # Assuming average charge for a vehicle is ₹15

print(f"\nTotal Revenue Over 30 Days: ₹{total_revenue:.2f}")
print(f"Total Lost Revenue Due to Lost Customers: ₹{lost_revenue:.2f}")
# Out:
# Parking Duration: 71.78 minutes, Charge: ₹50.00
# Parking Duration: 23.18 minutes, Charge: ₹15.00
# Parking Duration: 33.28 minutes, Charge: ₹25.00
# Parking Duration: 7.59 minutes, Charge: ₹15.00
# Parking Duration: 54.57 minutes, Charge: ₹25.00
# Parking Duration: 24.55 minutes, Charge: ₹15.00
# Parking Duration: 31.47 minutes, Charge: ₹25.00
# Parking Duration: 7.19 minutes, Charge: ₹15.00
# Parking Duration: 17.67 minutes, Charge: ₹15.00
# Parking Duration: 18.33 minutes, Charge: ₹15.00
# Parking Duration: 49.24 minutes, Charge: ₹25.00
# Parking Duration: 104.87 minutes, Charge: ₹50.00
# Parking Duration: 217.41 minutes, Charge: ₹100.00
# Parking Duration: 211.74 minutes, Charge: ₹100.00
# Parking Duration: 55.54 minutes, Charge: ₹25.00
# Parking Duration: 87.19 minutes, Charge: ₹50.00
# Parking Duration: 18.20 minutes, Charge: ₹15.00
# Parking Duration: 57.79 minutes, Charge: ₹25.00
# Parking Duration: 60.86 minutes, Charge: ₹50.00
# Parking Duration: 7.18 minutes, Charge: ₹15.00
# Parking Duration: 146.36 minutes, Charge: ₹75.00
# Parking Duration: 61.83 minutes, Charge: ₹50.00
# Parking Duration: 2.35 minutes, Charge: ₹15.00
# Parking Duration: 29.06 minutes, Charge: ₹15.00
# Parking Duration: 56.29 minutes, Charge: ₹25.00
# Parking Duration: 72.71 minutes, Charge: ₹50.00
# Parking Duration: 23.83 minutes, Charge: ₹15.00
# Parking Duration: 29.47 minutes, Charge: ₹15.00
# Parking Duration: 55.16 minutes, Charge: ₹25.00
# Parking Duration: 136.30 minutes, Charge: ₹75.00
# Parking Duration: 3.87 minutes, Charge: ₹15.00
# Parking Duration: 7.65 minutes, Charge: ₹15.00
# Parking Duration: 131.84 minutes, Charge: ₹75.00
# Parking Duration: 109.11 minutes, Charge: ₹50.00
# Parking Duration: 16.02 minutes, Charge: ₹15.00
# Parking Duration: 28.55 minutes, Charge: ₹15.00
# Parking Duration: 144.89 minutes, Charge: ₹75.00
# Parking Duration: 20.02 minutes, Charge: ₹15.00
# Parking Duration: 20.54 minutes, Charge: ₹15.00
# Parking Duration: 90.79 minutes, Charge: ₹50.00
# Parking Duration: 41.25 minutes, Charge: ₹25.00
# Parking Duration: 112.82 minutes, Charge: ₹50.00
# Parking Duration: 27.72 minutes, Charge: ₹15.00
# Parking Duration: 15.89 minutes, Charge: ₹15.00
# Parking Duration: 62.27 minutes, Charge: ₹50.00
# Parking Duration: 71.37 minutes, Charge: ₹50.00
# Parking Duration: 119.56 minutes, Charge: ₹50.00
# Parking Duration: 47.56 minutes, Charge: ₹25.00
# Parking Duration: 55.77 minutes, Charge: ₹25.00
# Parking Duration: 75.76 minutes, Charge: ₹50.00
# Parking Duration: 45.78 minutes, Charge: ₹25.00
# Parking Duration: 54.02 minutes, Charge: ₹25.00
# Parking Duration: 21.48 minutes, Charge: ₹15.00
# Parking Duration: 253.06 minutes, Charge: ₹125.00
# Parking Duration: 44.72 minutes, Charge: ₹25.00
# Parking Duration: 15.71 minutes, Charge: ₹15.00
# Parking Duration: 4.65 minutes, Charge: ₹15.00
# Parking Duration: 43.87 minutes, Charge: ₹25.00
# Parking Duration: 58.36 minutes, Charge: ₹25.00
# Parking Duration: 28.09 minutes, Charge: ₹15.00
# Parking Duration: 40.17 minutes, Charge: ₹25.00
# Parking Duration: 14.40 minutes, Charge: ₹15.00
# Parking Duration: 2.70 minutes, Charge: ₹15.00
# Parking Duration: 48.44 minutes, Charge: ₹25.00
# Parking Duration: 178.43 minutes, Charge: ₹75.00
# Parking Duration: 19.73 minutes, Charge: ₹15.00
# Parking Duration: 16.47 minutes, Charge: ₹15.00
# Parking Duration: 10.99 minutes, Charge: ₹15.00
# Parking Duration: 92.40 minutes, Charge: ₹50.00
# Parking Duration: 27.70 minutes, Charge: ₹15.00
# Parking Duration: 30.30 minutes, Charge: ₹25.00
# Parking Duration: 45.70 minutes, Charge: ₹25.00
# Parking Duration: 15.04 minutes, Charge: ₹15.00
# Parking Duration: 65.42 minutes, Charge: ₹50.00
# Parking Duration: 26.95 minutes, Charge: ₹15.00
# Parking Duration: 49.76 minutes, Charge: ₹25.00
# Parking Duration: 74.52 minutes, Charge: ₹50.00
# Parking Duration: 91.95 minutes, Charge: ₹50.00
# Parking Duration: 0.84 minutes, Charge: ₹15.00
# Parking Duration: 81.62 minutes, Charge: ₹50.00
# Parking Duration: 19.42 minutes, Charge: ₹15.00
# Parking Duration: 181.81 minutes, Charge: ₹100.00
# Parking Duration: 207.91 minutes, Charge: ₹100.00
# Parking Duration: 170.78 minutes, Charge: ₹75.00
# Parking Duration: 71.06 minutes, Charge: ₹50.00
# Parking Duration: 61.42 minutes, Charge: ₹50.00
# Parking Duration: 234.45 minutes, Charge: ₹100.00
# Parking Duration: 70.33 minutes, Charge: ₹50.00
# Parking Duration: 31.04 minutes, Charge: ₹25.00
# Parking Duration: 15.25 minutes, Charge: ₹15.00
# Parking Duration: 36.26 minutes, Charge: ₹25.00
# Parking Duration: 14.41 minutes, Charge: ₹15.00
# Parking Duration: 18.81 minutes, Charge: ₹15.00
# Parking Duration: 16.11 minutes, Charge: ₹15.00
# Parking Duration: 43.11 minutes, Charge: ₹25.00
# Parking Duration: 14.02 minutes, Charge: ₹15.00
# Parking Duration: 78.60 minutes, Charge: ₹50.00
# Parking Duration: 151.67 minutes, Charge: ₹75.00
# Parking Duration: 6.38 minutes, Charge: ₹15.00
# Parking Duration: 144.72 minutes, Charge: ₹75.00
# Parking Duration: 112.37 minutes, Charge: ₹50.00
# Parking Duration: 65.86 minutes, Charge: ₹50.00
# Parking Duration: 5.31 minutes, Charge: ₹15.00
# Parking Duration: 0.99 minutes, Charge: ₹15.00
# Parking Duration: 23.20 minutes, Charge: ₹15.00
# Parking Duration: 87.14 minutes, Charge: ₹50.00
# Parking Duration: 10.68 minutes, Charge: ₹15.00
# Parking Duration: 0.82 minutes, Charge: ₹15.00
# Parking Duration: 145.12 minutes, Charge: ₹75.00
# Parking Duration: 1.65 minutes, Charge: ₹15.00
# Parking Duration: 39.96 minutes, Charge: ₹25.00
# Parking Duration: 33.04 minutes, Charge: ₹25.00
# Parking Duration: 92.73 minutes, Charge: ₹50.00
# Parking Duration: 3.30 minutes, Charge: ₹15.00
# Parking Duration: 57.95 minutes, Charge: ₹25.00
# Parking Duration: 27.72 minutes, Charge: ₹15.00
# Parking Duration: 172.21 minutes, Charge: ₹75.00
# Parking Duration: 75.71 minutes, Charge: ₹50.00
# Parking Duration: 42.93 minutes, Charge: ₹25.00
# Parking Duration: 80.49 minutes, Charge: ₹50.00
# Parking Duration: 3.30 minutes, Charge: ₹15.00
# Parking Duration: 52.30 minutes, Charge: ₹25.00
# Parking Duration: 83.61 minutes, Charge: ₹50.00
# Parking Duration: 9.90 minutes, Charge: ₹15.00
# Parking Duration: 4.47 minutes, Charge: ₹15.00
# Parking Duration: 14.83 minutes, Charge: ₹15.00
# Parking Duration: 47.76 minutes, Charge: ₹25.00
# Parking Duration: 81.91 minutes, Charge: ₹50.00
# Parking Duration: 189.73 minutes, Charge: ₹100.00
# Parking Duration: 43.23 minutes, Charge: ₹25.00
# Parking Duration: 12.51 minutes, Charge: ₹15.00
# Parking Duration: 78.69 minutes, Charge: ₹50.00
# Parking Duration: 212.87 minutes, Charge: ₹100.00
# Parking Duration: 95.10 minutes, Charge: ₹50.00
# Parking Duration: 84.07 minutes, Charge: ₹50.00
# Parking Duration: 25.49 minutes, Charge: ₹15.00
# Parking Duration: 15.65 minutes, Charge: ₹15.00
# Parking Duration: 19.24 minutes, Charge: ₹15.00
# Parking Duration: 3.60 minutes, Charge: ₹15.00
# Parking Duration: 37.35 minutes, Charge: ₹25.00
# Parking Duration: 74.63 minutes, Charge: ₹50.00
# Parking Duration: 15.40 minutes, Charge: ₹15.00
# Parking Duration: 229.81 minutes, Charge: ₹100.00
# Parking Duration: 119.22 minutes, Charge: ₹50.00
# Parking Duration: 39.18 minutes, Charge: ₹25.00
# Parking Duration: 96.00 minutes, Charge: ₹50.00
# Parking Duration: 29.76 minutes, Charge: ₹15.00
# Parking Duration: 9.22 minutes, Charge: ₹15.00
# Parking Duration: 70.01 minutes, Charge: ₹50.00
# Parking Duration: 48.29 minutes, Charge: ₹25.00
# Parking Duration: 66.77 minutes, Charge: ₹50.00
# Parking Duration: 14.94 minutes, Charge: ₹15.00
# Parking Duration: 90.62 minutes, Charge: ₹50.00
# Parking Duration: 34.51 minutes, Charge: ₹25.00
# Parking Duration: 21.01 minutes, Charge: ₹15.00
# Parking Duration: 83.67 minutes, Charge: ₹50.00
# Parking Duration: 55.51 minutes, Charge: ₹25.00
# Parking Duration: 33.56 minutes, Charge: ₹25.00
# Parking Duration: 1.41 minutes, Charge: ₹15.00
# Parking Duration: 8.79 minutes, Charge: ₹15.00
# Parking Duration: 104.26 minutes, Charge: ₹50.00
# Parking Duration: 81.51 minutes, Charge: ₹50.00
# Parking Duration: 30.01 minutes, Charge: ₹25.00
# Parking Duration: 32.88 minutes, Charge: ₹25.00
# Parking Duration: 10.16 minutes, Charge: ₹15.00
# Parking Duration: 129.50 minutes, Charge: ₹75.00
# Parking Duration: 20.63 minutes, Charge: ₹15.00
# Parking Duration: 32.39 minutes, Charge: ₹25.00
# Parking Duration: 45.41 minutes, Charge: ₹25.00
# Parking Duration: 14.54 minutes, Charge: ₹15.00
# Parking Duration: 107.11 minutes, Charge: ₹50.00
# Parking Duration: 4.57 minutes, Charge: ₹15.00
# Parking Duration: 51.43 minutes, Charge: ₹25.00
# Parking Duration: 47.68 minutes, Charge: ₹25.00
# Parking Duration: 19.58 minutes, Charge: ₹15.00
# Parking Duration: 22.41 minutes, Charge: ₹15.00
# Parking Duration: 86.01 minutes, Charge: ₹50.00
# Parking Duration: 63.37 minutes, Charge: ₹50.00
# Parking Duration: 50.72 minutes, Charge: ₹25.00
# Parking Duration: 126.57 minutes, Charge: ₹75.00
# Parking Duration: 15.71 minutes, Charge: ₹15.00
# Parking Duration: 140.36 minutes, Charge: ₹75.00
# Parking Duration: 5.12 minutes, Charge: ₹15.00
# Parking Duration: 86.30 minutes, Charge: ₹50.00
# Parking Duration: 20.65 minutes, Charge: ₹15.00
# Parking Duration: 32.41 minutes, Charge: ₹25.00
# Parking Duration: 29.08 minutes, Charge: ₹15.00
# Parking Duration: 58.79 minutes, Charge: ₹25.00
# Parking Duration: 16.05 minutes, Charge: ₹15.00
# Parking Duration: 120.64 minutes, Charge: ₹75.00
# Parking Duration: 12.98 minutes, Charge: ₹15.00
# Parking Duration: 89.40 minutes, Charge: ₹50.00
# Parking Duration: 115.44 minutes, Charge: ₹50.00
# Parking Arrival Pattern Over 30 Days:
#         8:00  9:00  10:00  11:00  12:00  13:00  14:00  15:00  16:00  17:00  \
# Day 1   18.0  14.0   12.0    8.0   41.0   31.0   36.0   36.0   32.0   44.0
# Day 2   11.0  13.0    7.0   10.0   32.0   45.0   49.0   51.0   41.0   40.0
# Day 3   15.0   9.0    7.0    6.0   30.0   38.0   51.0   34.0   47.0   39.0
# Day 4   20.0   9.0   10.0   19.0   37.0   42.0   35.0   36.0   44.0   36.0
# Day 5   11.0   9.0   11.0   10.0   40.0   36.0   42.0   37.0   52.0   40.0
# Day 6   18.0  22.0   20.0   10.0   47.0   51.0   56.0   53.0   60.0   59.0
# Day 7   20.0  17.0    8.0   18.0   58.0   53.0   57.0   58.0   53.0   51.0
# Day 8   15.0  14.0   14.0   10.0   36.0   41.0   44.0   31.0   32.0   42.0
# Day 9   13.0  15.0   14.0   15.0   32.0   34.0   28.0   57.0   39.0   43.0
# Day 10  21.0  11.0   14.0   12.0   43.0   32.0   32.0   32.0   34.0   48.0
# Day 11  13.0  14.0   16.0   12.0   32.0   41.0   43.0   37.0   45.0   35.0
# Day 12  11.0  12.0   15.0   12.0   40.0   35.0   50.0   36.0   38.0   37.0
# Day 13  16.0  18.0   22.0   16.0   60.0   60.0   64.0   49.0   50.0   54.0
# Day 14  13.0  14.0   23.0   15.0   49.0   62.0   54.0   50.0   47.0   59.0
# Day 15   9.0  16.0   16.0   10.0   47.0   50.0   47.0   50.0   39.0   46.0
# Day 16  20.0  10.0   11.0   11.0   36.0   42.0   29.0   32.0   45.0   33.0
# Day 17   7.0  10.0   14.0   12.0   37.0   38.0   37.0   30.0   40.0   39.0
# Day 18  13.0  11.0   16.0    8.0   36.0   51.0   34.0   36.0   30.0   31.0
# Day 19  18.0  11.0   15.0   12.0   31.0   40.0   40.0   47.0   42.0   32.0
# Day 20  19.0  20.0   11.0   17.0   54.0   74.0   54.0   69.0   45.0   74.0
# Day 21  12.0  11.0   25.0   22.0   47.0   58.0   42.0   53.0   55.0   57.0
# Day 22  19.0  18.0    6.0   13.0   36.0   42.0   41.0   38.0   30.0   40.0
# Day 23  13.0   8.0   11.0    8.0   33.0   39.0   46.0   43.0   39.0   39.0
# Day 24  10.0  13.0   15.0    7.0   35.0   42.0   31.0   34.0   29.0   40.0
# Day 25  12.0  13.0   10.0   11.0   44.0   49.0   33.0   45.0   48.0   37.0
