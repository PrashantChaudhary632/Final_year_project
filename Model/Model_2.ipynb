# %%
import simpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Simulation parameters
SIM_DURATION = 30 * 12 * 60  # 30 days, 12 hours per day (8 AM to 8 PM)
CAPACITY = 250
WILLINGNESS_TO_VISIT = 0.80  # 80% willingness to visit
TARGET_LOST_PERCENTAGE = 10  # Target 10% lost customers
TOLERANCE = 0.5  # Allowable deviation from the target percentage

# Arrival rates based on the day of the week and time slots
ARRIVAL_RATES = {
    'Sunday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Monday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Tuesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Wednesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Thursday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Friday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)],
    'Saturday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)]
}

# Initialize data for tracking arrivals, inter-arrival times, parking durations, revenue, and parking space utilization
def initialize_data():
    global arrival_pattern, inter_arrival_times, parking_durations, total_revenue, lost_customers, parked_customers, utilization_data
    arrival_pattern = np.zeros((30, 12))  # 30 days, 12 hours per day (8 AM to 8 PM)
    inter_arrival_times = [[] for _ in range(30 * 12)]  # List of lists for storing inter-arrival times for each time slot
    parking_durations = []  # List to store parking durations
    total_revenue = 0  # Total revenue accumulator
    lost_customers = 0  # Lost customers accumulator
    parked_customers = 0  # Parked customers accumulator
    utilization_data = []  # List to store occupancy data for utilization calculation

def get_arrival_rate(day, hour):
    """Return the arrival rate based on the day and hour."""
    for start, end, rate in ARRIVAL_RATES[day]:
        if start <= hour < end:
            return rate
    return 0

def calculate_charge(parking_duration):
    """Calculate the charge based on parking duration with ceiling logic."""
    if parking_duration < 30:
        return 15
    else:
        hours = np.ceil(parking_duration / 60)  # Round up to the nearest hour
        return 25 * hours  # Charge ₹25 per hour

def vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time):
    """Simulates vehicle parking behavior, tracks arrivals, inter-arrival times, and calculates revenue."""
    global total_revenue, lost_customers, parked_customers
    
    # Check if the vehicle decides to park based on willingness to visit
    if np.random.random() > WILLINGNESS_TO_VISIT:
        lost_customers += 1
        return  # Vehicle leaves without parking

    # Generate parking duration (in minutes)
    parking_duration = np.random.exponential(60)  # Exponential distribution with mean 60 minutes
    
    # Store parking duration
    parking_durations.append(parking_duration)
    
    # Calculate the charge based on parking duration
    charge = calculate_charge(parking_duration)
    
    # Update total revenue
    total_revenue += charge
    parked_customers += 1  # Increment parked customers counter
    
    with parking_lot.request() as request:
        yield request
        # Update occupancy data
        current_time = env.now
        num_vehicles = len(parking_lot.users)
        utilization_data.append((current_time, num_vehicles))
        yield env.timeout(parking_duration)
        # Track arrivals for the specific day and hour
        arrival_pattern[day_index, hour_index] += 1  # Use correct indexing for Numpy arrays
        # Store the inter-arrival time
        inter_arrival_times[day_index * 12 + hour_index].append(inter_arrival_time)

def arrival_process(env, parking_lot, day, day_index):
    """Simulates the arrival process based on the day and time."""
    global parked_customers, lost_customers
    while env.now < (day_index + 1) * 12 * 60:  # Simulate only 12 hours per day
        current_hour = (env.now // 60) % 12 + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
        rate = get_arrival_rate(day, current_hour)
        
        # Determine the hour index (0 to 11 for 8 AM to 8 PM)
        hour_index = int(current_hour - 8)  # Adjust index to match 0-11 range
        
        if 0 <= hour_index < 12:  # Ensure hour_index is within valid bounds
            if rate > 0:
                inter_arrival_time = np.random.exponential(60 / rate)  # Convert hourly rate to inter-arrival time
                yield env.timeout(inter_arrival_time)
                env.process(vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time))
            else:
                yield env.timeout(1)  # Wait for 1 minute if no arrival

def run_simulation():
    """Runs the simulation for 30 days."""
    global total_revenue, lost_customers, parked_customers
    env = simpy.Environment()
    parking_lot = simpy.Resource(env, capacity=CAPACITY)

    for day_index in range(30):
        day_name = list(ARRIVAL_RATES.keys())[day_index % 7]  # Cycle through days of the week
        env.process(arrival_process(env, parking_lot, day_name, day_index))

        # Simulate 12 hours of the current day
        env.run(until=(day_index + 1) * 12 * 60)

def adjust_arrival_rates(percentage_lost_customers):
    """Adjust arrival rates based on the percentage of lost customers."""
    # Ensure adjustment factor does not reduce rates to zero
    adjustment_factor = 1.05 if percentage_lost_customers < TARGET_LOST_PERCENTAGE else 0.95

    print(f"Adjusting arrival rates with factor: {adjustment_factor}")

    # Update arrival rates based on the adjustment factor
    updated_arrival_rates = {}
    for day in ARRIVAL_RATES:
        updated_slots = []
        for start, end, rate in ARRIVAL_RATES[day]:
            # Ensure rate does not fall below a minimum threshold
            new_rate = max(rate * adjustment_factor, 0.1)  # Avoid zero rates
            updated_slots.append((start, end, new_rate))
        updated_arrival_rates[day] = updated_slots
    
    return updated_arrival_rates

# Dynamic adjustment loop
acceptable_range = (TARGET_LOST_PERCENTAGE - TOLERANCE, TARGET_LOST_PERCENTAGE + TOLERANCE)
while True:
    initialize_data()  # Reset all data accumulators
    run_simulation()  # Run the parking lot simulation

    # Calculate percentage of lost customers
    total_attempted_arrivals = parked_customers + lost_customers
    percentage_lost_customers = (lost_customers / total_attempted_arrivals) * 100 if total_attempted_arrivals > 0 else 0

    # Calculate average parking duration
    avg_parking_duration = np.mean(parking_durations) if parking_durations else 0

    # Calculate average inter-arrival time
    all_inter_arrival_times = [time for slot in inter_arrival_times for time in slot]  # Flatten list of lists
    avg_inter_arrival_time = np.mean(all_inter_arrival_times) if all_inter_arrival_times else 0

    # Calculate total parking space utilization
    time_slot_utilization = {'8-11:59': [], '12-16:59': [], '17-20:00': []}
    total_time_per_slot = {'8-11:59': 4 * 60 * 30, '12-16:59': 5 * 60 * 30, '17-20:00': 3 * 60 * 30}  # Total time per slot

    # Utility function to get time slot based on the hour
    def get_time_slot(hour):
        if 8 <= hour < 12:
            return '8-11:59'
        elif 12 <= hour < 17:
            return '12-16:59'
        elif 17 <= hour < 20:
            return '17-20:00'
        return None

    # Compute the total occupied time based on occupancy data and categorize by time slots
    previous_time = 0
    for current_time, num_vehicles in utilization_data:
        hour = int((current_time // 60) % 12) + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
        time_slot = get_time_slot(hour)
        if time_slot:
            time_spent = current_time - previous_time
            time_slot_utilization[time_slot].append(time_spent * (num_vehicles / CAPACITY))
        previous_time = current_time

    # Calculate average utilization for each time slot
    average_utilization_by_slot = {
        slot: (np.sum(time_slot_utilization[slot]) / total_time_per_slot[slot]) * 100
        for slot in time_slot_utilization
    }

    # Print relevant factors
    print(f"\nSimulation Results after Adjusting Arrival Rates:")
    print(f"Current Lost Customer Percentage: {percentage_lost_customers:.2f}%")
    print(f"Total Revenue: ₹{total_revenue:.2f}")
    print(f"Average Parking Duration: {avg_parking_duration:.2f} minutes")
    print(f"Average Inter-Arrival Time: {avg_inter_arrival_time:.2f} minutes")
    print(f"Total Parked Customers: {parked_customers}")
    print(f"Total Lost Customers: {lost_customers}")

    # Print average parking space utilization by time slot
    print("\nAverage Parking Space Utilization by Time Slot:")
    for slot, utilization in average_utilization_by_slot.items():
        print(f"{slot}: {utilization:.2f}%")
    
    # Print adjusted arrival rates
    print("\nUpdated Arrival Rates by Time Slot:")
    for day, slots in ARRIVAL_RATES.items():
        print(f"\n{day}:")
        for start, end, rate in slots:
            print(f"  {start}:00 - {end}:00: {rate:.2f} vehicles/hour")

    # Check if the lost customer percentage is within the acceptable range
    if acceptable_range[0] <= percentage_lost_customers <= acceptable_range[1]:
        print(f"Lost customer percentage is within the acceptable range: {percentage_lost_customers:.2f}%")
        break
    else:
        print(f"Adjusting arrival rates...")
        ARRIVAL_RATES = adjust_arrival_rates(percentage_lost_customers)
# Out:
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.69%
# Total Revenue: ₹433385.00
# Average Parking Duration: 59.68 minutes
# Average Inter-Arrival Time: 1.40 minutes
# Total Parked Customers: 12204
# Total Lost Customers: 3183
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 7.92%
# 12-16:59: 14.87%
# 17-20:00: 18.20%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 15.00 vehicles/hour
#   12:00 - 17:00: 50.00 vehicles/hour
#   17:00 - 20:00: 50.00 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 15.00 vehicles/hour
#   12:00 - 17:00: 50.00 vehicles/hour
#   17:00 - 20:00: 50.00 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 15.00 vehicles/hour
#   12:00 - 17:00: 50.00 vehicles/hour
#   17:00 - 20:00: 50.00 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 15.00 vehicles/hour
#   12:00 - 17:00: 50.00 vehicles/hour
#   17:00 - 20:00: 50.00 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 15.00 vehicles/hour
#   12:00 - 17:00: 50.00 vehicles/hour
#   17:00 - 20:00: 50.00 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 20.00 vehicles/hour
#   12:00 - 17:00: 70.00 vehicles/hour
#   17:00 - 20:00: 80.00 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 20.00 vehicles/hour
#   12:00 - 17:00: 70.00 vehicles/hour
#   17:00 - 20:00: 80.00 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.76%
# Total Revenue: ₹428260.00
# Average Parking Duration: 60.01 minutes
# Average Inter-Arrival Time: 1.44 minutes
# Total Parked Customers: 12023
# Total Lost Customers: 2961
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 7.46%
# 12-16:59: 15.36%
# 17-20:00: 17.52%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 14.25 vehicles/hour
#   12:00 - 17:00: 47.50 vehicles/hour
#   17:00 - 20:00: 47.50 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 14.25 vehicles/hour
#   12:00 - 17:00: 47.50 vehicles/hour
#   17:00 - 20:00: 47.50 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 14.25 vehicles/hour
#   12:00 - 17:00: 47.50 vehicles/hour
#   17:00 - 20:00: 47.50 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 14.25 vehicles/hour
#   12:00 - 17:00: 47.50 vehicles/hour
#   17:00 - 20:00: 47.50 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 14.25 vehicles/hour
#   12:00 - 17:00: 47.50 vehicles/hour
#   17:00 - 20:00: 47.50 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 19.00 vehicles/hour
#   12:00 - 17:00: 66.50 vehicles/hour
#   17:00 - 20:00: 76.00 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 19.00 vehicles/hour
#   12:00 - 17:00: 66.50 vehicles/hour
#   17:00 - 20:00: 76.00 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.20%
# Total Revenue: ₹401515.00
# Average Parking Duration: 60.95 minutes
# Average Inter-Arrival Time: 1.55 minutes
# Total Parked Customers: 11141
# Total Lost Customers: 2820
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 7.41%
# 12-16:59: 13.84%
# 17-20:00: 17.03%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 13.54 vehicles/hour
#   12:00 - 17:00: 45.12 vehicles/hour
#   17:00 - 20:00: 45.12 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 13.54 vehicles/hour
#   12:00 - 17:00: 45.12 vehicles/hour
#   17:00 - 20:00: 45.12 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 13.54 vehicles/hour
#   12:00 - 17:00: 45.12 vehicles/hour
#   17:00 - 20:00: 45.12 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 13.54 vehicles/hour
#   12:00 - 17:00: 45.12 vehicles/hour
#   17:00 - 20:00: 45.12 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 13.54 vehicles/hour
#   12:00 - 17:00: 45.12 vehicles/hour
#   17:00 - 20:00: 45.12 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 18.05 vehicles/hour
#   12:00 - 17:00: 63.17 vehicles/hour
#   17:00 - 20:00: 72.20 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 18.05 vehicles/hour
#   12:00 - 17:00: 63.17 vehicles/hour
#   17:00 - 20:00: 72.20 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.77%
# Total Revenue: ₹372785.00
# Average Parking Duration: 60.27 minutes
# Average Inter-Arrival Time: 1.66 minutes
# Total Parked Customers: 10440
# Total Lost Customers: 2572
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 7.09%
# 12-16:59: 12.64%
# 17-20:00: 15.81%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 12.86 vehicles/hour
#   12:00 - 17:00: 42.87 vehicles/hour
#   17:00 - 20:00: 42.87 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 12.86 vehicles/hour
#   12:00 - 17:00: 42.87 vehicles/hour
#   17:00 - 20:00: 42.87 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 12.86 vehicles/hour
#   12:00 - 17:00: 42.87 vehicles/hour
#   17:00 - 20:00: 42.87 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 12.86 vehicles/hour
#   12:00 - 17:00: 42.87 vehicles/hour
#   17:00 - 20:00: 42.87 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 12.86 vehicles/hour
#   12:00 - 17:00: 42.87 vehicles/hour
#   17:00 - 20:00: 42.87 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 17.15 vehicles/hour
#   12:00 - 17:00: 60.02 vehicles/hour
#   17:00 - 20:00: 68.59 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 17.15 vehicles/hour
#   12:00 - 17:00: 60.02 vehicles/hour
#   17:00 - 20:00: 68.59 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.04%
# Total Revenue: ₹352585.00
# Average Parking Duration: 59.46 minutes
# Average Inter-Arrival Time: 1.73 minutes
# Total Parked Customers: 9986
# Total Lost Customers: 2503
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 6.55%
# 12-16:59: 12.27%
# 17-20:00: 14.58%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 12.22 vehicles/hour
#   12:00 - 17:00: 40.73 vehicles/hour
#   17:00 - 20:00: 40.73 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 12.22 vehicles/hour
#   12:00 - 17:00: 40.73 vehicles/hour
#   17:00 - 20:00: 40.73 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 12.22 vehicles/hour
#   12:00 - 17:00: 40.73 vehicles/hour
#   17:00 - 20:00: 40.73 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 12.22 vehicles/hour
#   12:00 - 17:00: 40.73 vehicles/hour
#   17:00 - 20:00: 40.73 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 12.22 vehicles/hour
#   12:00 - 17:00: 40.73 vehicles/hour
#   17:00 - 20:00: 40.73 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 16.29 vehicles/hour
#   12:00 - 17:00: 57.02 vehicles/hour
#   17:00 - 20:00: 65.16 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 16.29 vehicles/hour
#   12:00 - 17:00: 57.02 vehicles/hour
#   17:00 - 20:00: 65.16 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.63%
# Total Revenue: ₹340095.00
# Average Parking Duration: 60.63 minutes
# Average Inter-Arrival Time: 1.84 minutes
# Total Parked Customers: 9476
# Total Lost Customers: 2314
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 6.31%
# 12-16:59: 11.77%
# 17-20:00: 14.23%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 11.61 vehicles/hour
#   12:00 - 17:00: 38.69 vehicles/hour
#   17:00 - 20:00: 38.69 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 11.61 vehicles/hour
#   12:00 - 17:00: 38.69 vehicles/hour
#   17:00 - 20:00: 38.69 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 11.61 vehicles/hour
#   12:00 - 17:00: 38.69 vehicles/hour
#   17:00 - 20:00: 38.69 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 11.61 vehicles/hour
#   12:00 - 17:00: 38.69 vehicles/hour
#   17:00 - 20:00: 38.69 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 11.61 vehicles/hour
#   12:00 - 17:00: 38.69 vehicles/hour
#   17:00 - 20:00: 38.69 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 15.48 vehicles/hour
#   12:00 - 17:00: 54.16 vehicles/hour
#   17:00 - 20:00: 61.90 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 15.48 vehicles/hour
#   12:00 - 17:00: 54.16 vehicles/hour
#   17:00 - 20:00: 61.90 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.33%
# Total Revenue: ₹328870.00
# Average Parking Duration: 60.49 minutes
# Average Inter-Arrival Time: 1.89 minutes
# Total Parked Customers: 9176
# Total Lost Customers: 2342
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 6.33%
# 12-16:59: 11.23%
# 17-20:00: 13.73%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 11.03 vehicles/hour
#   12:00 - 17:00: 36.75 vehicles/hour
#   17:00 - 20:00: 36.75 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 11.03 vehicles/hour
#   12:00 - 17:00: 36.75 vehicles/hour
#   17:00 - 20:00: 36.75 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 11.03 vehicles/hour
#   12:00 - 17:00: 36.75 vehicles/hour
#   17:00 - 20:00: 36.75 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 11.03 vehicles/hour
#   12:00 - 17:00: 36.75 vehicles/hour
#   17:00 - 20:00: 36.75 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 11.03 vehicles/hour
#   12:00 - 17:00: 36.75 vehicles/hour
#   17:00 - 20:00: 36.75 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 14.70 vehicles/hour
#   12:00 - 17:00: 51.46 vehicles/hour
#   17:00 - 20:00: 58.81 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 14.70 vehicles/hour
#   12:00 - 17:00: 51.46 vehicles/hour
#   17:00 - 20:00: 58.81 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.32%
# Total Revenue: ₹304970.00
# Average Parking Duration: 59.67 minutes
# Average Inter-Arrival Time: 1.99 minutes
# Total Parked Customers: 8580
# Total Lost Customers: 2188
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.84%
# 12-16:59: 10.34%
# 17-20:00: 12.71%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 10.48 vehicles/hour
#   12:00 - 17:00: 34.92 vehicles/hour
#   17:00 - 20:00: 34.92 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 10.48 vehicles/hour
#   12:00 - 17:00: 34.92 vehicles/hour
#   17:00 - 20:00: 34.92 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 10.48 vehicles/hour
#   12:00 - 17:00: 34.92 vehicles/hour
#   17:00 - 20:00: 34.92 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 10.48 vehicles/hour
#   12:00 - 17:00: 34.92 vehicles/hour
#   17:00 - 20:00: 34.92 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 10.48 vehicles/hour
#   12:00 - 17:00: 34.92 vehicles/hour
#   17:00 - 20:00: 34.92 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 13.97 vehicles/hour
#   12:00 - 17:00: 48.88 vehicles/hour
#   17:00 - 20:00: 55.87 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 13.97 vehicles/hour
#   12:00 - 17:00: 48.88 vehicles/hour
#   17:00 - 20:00: 55.87 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.09%
# Total Revenue: ₹291755.00
# Average Parking Duration: 59.55 minutes
# Average Inter-Arrival Time: 2.10 minutes
# Total Parked Customers: 8249
# Total Lost Customers: 2074
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.53%
# 12-16:59: 9.93%
# 17-20:00: 12.33%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 9.95 vehicles/hour
#   12:00 - 17:00: 33.17 vehicles/hour
#   17:00 - 20:00: 33.17 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 9.95 vehicles/hour
#   12:00 - 17:00: 33.17 vehicles/hour
#   17:00 - 20:00: 33.17 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 9.95 vehicles/hour
#   12:00 - 17:00: 33.17 vehicles/hour
#   17:00 - 20:00: 33.17 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 9.95 vehicles/hour
#   12:00 - 17:00: 33.17 vehicles/hour
#   17:00 - 20:00: 33.17 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 9.95 vehicles/hour
#   12:00 - 17:00: 33.17 vehicles/hour
#   17:00 - 20:00: 33.17 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 13.27 vehicles/hour
#   12:00 - 17:00: 46.44 vehicles/hour
#   17:00 - 20:00: 53.07 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 13.27 vehicles/hour
#   12:00 - 17:00: 46.44 vehicles/hour
#   17:00 - 20:00: 53.07 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.16%
# Total Revenue: ₹275480.00
# Average Parking Duration: 58.93 minutes
# Average Inter-Arrival Time: 2.17 minutes
# Total Parked Customers: 7838
# Total Lost Customers: 1979
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.04%
# 12-16:59: 9.57%
# 17-20:00: 11.38%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 9.45 vehicles/hour
#   12:00 - 17:00: 31.51 vehicles/hour
#   17:00 - 20:00: 31.51 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 9.45 vehicles/hour
#   12:00 - 17:00: 31.51 vehicles/hour
#   17:00 - 20:00: 31.51 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 9.45 vehicles/hour
#   12:00 - 17:00: 31.51 vehicles/hour
#   17:00 - 20:00: 31.51 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 9.45 vehicles/hour
#   12:00 - 17:00: 31.51 vehicles/hour
#   17:00 - 20:00: 31.51 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 9.45 vehicles/hour
#   12:00 - 17:00: 31.51 vehicles/hour
#   17:00 - 20:00: 31.51 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 12.60 vehicles/hour
#   12:00 - 17:00: 44.12 vehicles/hour
#   17:00 - 20:00: 50.42 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 12.60 vehicles/hour
#   12:00 - 17:00: 44.12 vehicles/hour
#   17:00 - 20:00: 50.42 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.02%
# Total Revenue: ₹267140.00
# Average Parking Duration: 60.75 minutes
# Average Inter-Arrival Time: 2.34 minutes
# Total Parked Customers: 7459
# Total Lost Customers: 1867
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.26%
# 12-16:59: 9.07%
# 17-20:00: 11.26%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 8.98 vehicles/hour
#   12:00 - 17:00: 29.94 vehicles/hour
#   17:00 - 20:00: 29.94 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 8.98 vehicles/hour
#   12:00 - 17:00: 29.94 vehicles/hour
#   17:00 - 20:00: 29.94 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 8.98 vehicles/hour
#   12:00 - 17:00: 29.94 vehicles/hour
#   17:00 - 20:00: 29.94 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 8.98 vehicles/hour
#   12:00 - 17:00: 29.94 vehicles/hour
#   17:00 - 20:00: 29.94 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 8.98 vehicles/hour
#   12:00 - 17:00: 29.94 vehicles/hour
#   17:00 - 20:00: 29.94 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 11.97 vehicles/hour
#   12:00 - 17:00: 41.91 vehicles/hour
#   17:00 - 20:00: 47.90 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 11.97 vehicles/hour
#   12:00 - 17:00: 41.91 vehicles/hour
#   17:00 - 20:00: 47.90 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.67%
# Total Revenue: ₹245535.00
# Average Parking Duration: 59.70 minutes
# Average Inter-Arrival Time: 2.53 minutes
# Total Parked Customers: 6921
# Total Lost Customers: 1695
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.39%
# 12-16:59: 8.64%
# 17-20:00: 10.17%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 8.53 vehicles/hour
#   12:00 - 17:00: 28.44 vehicles/hour
#   17:00 - 20:00: 28.44 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 8.53 vehicles/hour
#   12:00 - 17:00: 28.44 vehicles/hour
#   17:00 - 20:00: 28.44 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 8.53 vehicles/hour
#   12:00 - 17:00: 28.44 vehicles/hour
#   17:00 - 20:00: 28.44 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 8.53 vehicles/hour
#   12:00 - 17:00: 28.44 vehicles/hour
#   17:00 - 20:00: 28.44 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 8.53 vehicles/hour
#   12:00 - 17:00: 28.44 vehicles/hour
#   17:00 - 20:00: 28.44 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 11.38 vehicles/hour
#   12:00 - 17:00: 39.82 vehicles/hour
#   17:00 - 20:00: 45.50 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 11.38 vehicles/hour
#   12:00 - 17:00: 39.82 vehicles/hour
#   17:00 - 20:00: 45.50 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.08%
# Total Revenue: ₹240610.00
# Average Parking Duration: 59.85 minutes
# Average Inter-Arrival Time: 2.55 minutes
# Total Parked Customers: 6759
# Total Lost Customers: 1698
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.58%
# 12-16:59: 8.13%
# 17-20:00: 10.16%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 8.11 vehicles/hour
#   12:00 - 17:00: 27.02 vehicles/hour
#   17:00 - 20:00: 27.02 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 8.11 vehicles/hour
#   12:00 - 17:00: 27.02 vehicles/hour
#   17:00 - 20:00: 27.02 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 8.11 vehicles/hour
#   12:00 - 17:00: 27.02 vehicles/hour
#   17:00 - 20:00: 27.02 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 8.11 vehicles/hour
#   12:00 - 17:00: 27.02 vehicles/hour
#   17:00 - 20:00: 27.02 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 8.11 vehicles/hour
#   12:00 - 17:00: 27.02 vehicles/hour
#   17:00 - 20:00: 27.02 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 10.81 vehicles/hour
#   12:00 - 17:00: 37.83 vehicles/hour
#   17:00 - 20:00: 43.23 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 10.81 vehicles/hour
#   12:00 - 17:00: 37.83 vehicles/hour
#   17:00 - 20:00: 43.23 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.32%
# Total Revenue: ₹226465.00
# Average Parking Duration: 58.51 minutes
# Average Inter-Arrival Time: 2.70 minutes
# Total Parked Customers: 6478
# Total Lost Customers: 1551
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.08%
# 12-16:59: 7.80%
# 17-20:00: 9.52%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 7.70 vehicles/hour
#   12:00 - 17:00: 25.67 vehicles/hour
#   17:00 - 20:00: 25.67 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 7.70 vehicles/hour
#   12:00 - 17:00: 25.67 vehicles/hour
#   17:00 - 20:00: 25.67 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 7.70 vehicles/hour
#   12:00 - 17:00: 25.67 vehicles/hour
#   17:00 - 20:00: 25.67 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 7.70 vehicles/hour
#   12:00 - 17:00: 25.67 vehicles/hour
#   17:00 - 20:00: 25.67 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 7.70 vehicles/hour
#   12:00 - 17:00: 25.67 vehicles/hour
#   17:00 - 20:00: 25.67 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 10.27 vehicles/hour
#   12:00 - 17:00: 35.93 vehicles/hour
#   17:00 - 20:00: 41.07 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 10.27 vehicles/hour
#   12:00 - 17:00: 35.93 vehicles/hour
#   17:00 - 20:00: 41.07 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.67%
# Total Revenue: ₹216895.00
# Average Parking Duration: 59.71 minutes
# Average Inter-Arrival Time: 2.84 minutes
# Total Parked Customers: 6118
# Total Lost Customers: 1498
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.05%
# 12-16:59: 7.32%
# 17-20:00: 9.29%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 7.32 vehicles/hour
#   12:00 - 17:00: 24.38 vehicles/hour
#   17:00 - 20:00: 24.38 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 7.32 vehicles/hour
#   12:00 - 17:00: 24.38 vehicles/hour
#   17:00 - 20:00: 24.38 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 7.32 vehicles/hour
#   12:00 - 17:00: 24.38 vehicles/hour
#   17:00 - 20:00: 24.38 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 7.32 vehicles/hour
#   12:00 - 17:00: 24.38 vehicles/hour
#   17:00 - 20:00: 24.38 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 7.32 vehicles/hour
#   12:00 - 17:00: 24.38 vehicles/hour
#   17:00 - 20:00: 24.38 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 9.75 vehicles/hour
#   12:00 - 17:00: 34.14 vehicles/hour
#   17:00 - 20:00: 39.01 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 9.75 vehicles/hour
#   12:00 - 17:00: 34.14 vehicles/hour
#   17:00 - 20:00: 39.01 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.80%
# Total Revenue: ₹199330.00
# Average Parking Duration: 59.85 minutes
# Average Inter-Arrival Time: 3.11 minutes
# Total Parked Customers: 5594
# Total Lost Customers: 1381
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.75%
# 12-16:59: 6.67%
# 17-20:00: 8.54%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 6.95 vehicles/hour
#   12:00 - 17:00: 23.16 vehicles/hour
#   17:00 - 20:00: 23.16 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 6.95 vehicles/hour
#   12:00 - 17:00: 23.16 vehicles/hour
#   17:00 - 20:00: 23.16 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 6.95 vehicles/hour
#   12:00 - 17:00: 23.16 vehicles/hour
#   17:00 - 20:00: 23.16 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 6.95 vehicles/hour
#   12:00 - 17:00: 23.16 vehicles/hour
#   17:00 - 20:00: 23.16 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 6.95 vehicles/hour
#   12:00 - 17:00: 23.16 vehicles/hour
#   17:00 - 20:00: 23.16 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 9.27 vehicles/hour
#   12:00 - 17:00: 32.43 vehicles/hour
#   17:00 - 20:00: 37.06 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 9.27 vehicles/hour
#   12:00 - 17:00: 32.43 vehicles/hour
#   17:00 - 20:00: 37.06 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.13%
# Total Revenue: ₹194405.00
# Average Parking Duration: 60.30 minutes
# Average Inter-Arrival Time: 3.19 minutes
# Total Parked Customers: 5424
# Total Lost Customers: 1367
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.43%
# 12-16:59: 6.86%
# 17-20:00: 8.15%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 6.60 vehicles/hour
#   12:00 - 17:00: 22.01 vehicles/hour
#   17:00 - 20:00: 22.01 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 6.60 vehicles/hour
#   12:00 - 17:00: 22.01 vehicles/hour
#   17:00 - 20:00: 22.01 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 6.60 vehicles/hour
#   12:00 - 17:00: 22.01 vehicles/hour
#   17:00 - 20:00: 22.01 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 6.60 vehicles/hour
#   12:00 - 17:00: 22.01 vehicles/hour
#   17:00 - 20:00: 22.01 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 6.60 vehicles/hour
#   12:00 - 17:00: 22.01 vehicles/hour
#   17:00 - 20:00: 22.01 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 8.80 vehicles/hour
#   12:00 - 17:00: 30.81 vehicles/hour
#   17:00 - 20:00: 35.21 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 8.80 vehicles/hour
#   12:00 - 17:00: 30.81 vehicles/hour
#   17:00 - 20:00: 35.21 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.71%
# Total Revenue: ₹183915.00
# Average Parking Duration: 59.15 minutes
# Average Inter-Arrival Time: 3.32 minutes
# Total Parked Customers: 5213
# Total Lost Customers: 1280
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.36%
# 12-16:59: 6.44%
# 17-20:00: 7.54%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 6.27 vehicles/hour
#   12:00 - 17:00: 20.91 vehicles/hour
#   17:00 - 20:00: 20.91 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 6.27 vehicles/hour
#   12:00 - 17:00: 20.91 vehicles/hour
#   17:00 - 20:00: 20.91 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 6.27 vehicles/hour
#   12:00 - 17:00: 20.91 vehicles/hour
#   17:00 - 20:00: 20.91 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 6.27 vehicles/hour
#   12:00 - 17:00: 20.91 vehicles/hour
#   17:00 - 20:00: 20.91 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 6.27 vehicles/hour
#   12:00 - 17:00: 20.91 vehicles/hour
#   17:00 - 20:00: 20.91 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 8.36 vehicles/hour
#   12:00 - 17:00: 29.27 vehicles/hour
#   17:00 - 20:00: 33.45 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 8.36 vehicles/hour
#   12:00 - 17:00: 29.27 vehicles/hour
#   17:00 - 20:00: 33.45 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.77%
# Total Revenue: ₹173520.00
# Average Parking Duration: 59.46 minutes
# Average Inter-Arrival Time: 3.52 minutes
# Total Parked Customers: 4918
# Total Lost Customers: 1212
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.09%
# 12-16:59: 6.06%
# 17-20:00: 7.36%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 5.96 vehicles/hour
#   12:00 - 17:00: 19.86 vehicles/hour
#   17:00 - 20:00: 19.86 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 5.96 vehicles/hour
#   12:00 - 17:00: 19.86 vehicles/hour
#   17:00 - 20:00: 19.86 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 5.96 vehicles/hour
#   12:00 - 17:00: 19.86 vehicles/hour
#   17:00 - 20:00: 19.86 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 5.96 vehicles/hour
#   12:00 - 17:00: 19.86 vehicles/hour
#   17:00 - 20:00: 19.86 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 5.96 vehicles/hour
#   12:00 - 17:00: 19.86 vehicles/hour
#   17:00 - 20:00: 19.86 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 7.94 vehicles/hour
#   12:00 - 17:00: 27.81 vehicles/hour
#   17:00 - 20:00: 31.78 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 7.94 vehicles/hour
#   12:00 - 17:00: 27.81 vehicles/hour
#   17:00 - 20:00: 31.78 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.46%
# Total Revenue: ₹169300.00
# Average Parking Duration: 58.91 minutes
# Average Inter-Arrival Time: 3.63 minutes
# Total Parked Customers: 4809
# Total Lost Customers: 1162
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.30%
# 12-16:59: 5.78%
# 17-20:00: 6.92%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 5.66 vehicles/hour
#   12:00 - 17:00: 18.87 vehicles/hour
#   17:00 - 20:00: 18.87 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 5.66 vehicles/hour
#   12:00 - 17:00: 18.87 vehicles/hour
#   17:00 - 20:00: 18.87 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 5.66 vehicles/hour
#   12:00 - 17:00: 18.87 vehicles/hour
#   17:00 - 20:00: 18.87 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 5.66 vehicles/hour
#   12:00 - 17:00: 18.87 vehicles/hour
#   17:00 - 20:00: 18.87 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 5.66 vehicles/hour
#   12:00 - 17:00: 18.87 vehicles/hour
#   17:00 - 20:00: 18.87 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 7.55 vehicles/hour
#   12:00 - 17:00: 26.41 vehicles/hour
#   17:00 - 20:00: 30.19 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 7.55 vehicles/hour
#   12:00 - 17:00: 26.41 vehicles/hour
#   17:00 - 20:00: 30.19 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.02%
# Total Revenue: ₹156705.00
# Average Parking Duration: 60.13 minutes
# Average Inter-Arrival Time: 3.96 minutes
# Total Parked Customers: 4388
# Total Lost Customers: 1168
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.88%
# 12-16:59: 5.43%
# 17-20:00: 6.63%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 5.38 vehicles/hour
#   12:00 - 17:00: 17.92 vehicles/hour
#   17:00 - 20:00: 17.92 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 5.38 vehicles/hour
#   12:00 - 17:00: 17.92 vehicles/hour
#   17:00 - 20:00: 17.92 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 5.38 vehicles/hour
#   12:00 - 17:00: 17.92 vehicles/hour
#   17:00 - 20:00: 17.92 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 5.38 vehicles/hour
#   12:00 - 17:00: 17.92 vehicles/hour
#   17:00 - 20:00: 17.92 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 5.38 vehicles/hour
#   12:00 - 17:00: 17.92 vehicles/hour
#   17:00 - 20:00: 17.92 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 7.17 vehicles/hour
#   12:00 - 17:00: 25.09 vehicles/hour
#   17:00 - 20:00: 28.68 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 7.17 vehicles/hour
#   12:00 - 17:00: 25.09 vehicles/hour
#   17:00 - 20:00: 28.68 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.42%
# Total Revenue: ₹154205.00
# Average Parking Duration: 62.17 minutes
# Average Inter-Arrival Time: 4.18 minutes
# Total Parked Customers: 4229
# Total Lost Customers: 1019
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.79%
# 12-16:59: 5.49%
# 17-20:00: 6.57%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 5.11 vehicles/hour
#   12:00 - 17:00: 17.03 vehicles/hour
#   17:00 - 20:00: 17.03 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 5.11 vehicles/hour
#   12:00 - 17:00: 17.03 vehicles/hour
#   17:00 - 20:00: 17.03 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 5.11 vehicles/hour
#   12:00 - 17:00: 17.03 vehicles/hour
#   17:00 - 20:00: 17.03 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 5.11 vehicles/hour
#   12:00 - 17:00: 17.03 vehicles/hour
#   17:00 - 20:00: 17.03 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 5.11 vehicles/hour
#   12:00 - 17:00: 17.03 vehicles/hour
#   17:00 - 20:00: 17.03 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 6.81 vehicles/hour
#   12:00 - 17:00: 23.84 vehicles/hour
#   17:00 - 20:00: 27.24 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 6.81 vehicles/hour
#   12:00 - 17:00: 23.84 vehicles/hour
#   17:00 - 20:00: 27.24 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.05%
# Total Revenue: ₹141560.00
# Average Parking Duration: 61.03 minutes
# Average Inter-Arrival Time: 4.49 minutes
# Total Parked Customers: 3939
# Total Lost Customers: 927
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.67%
# 12-16:59: 4.89%
# 17-20:00: 6.00%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 4.85 vehicles/hour
#   12:00 - 17:00: 16.18 vehicles/hour
#   17:00 - 20:00: 16.18 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 4.85 vehicles/hour
#   12:00 - 17:00: 16.18 vehicles/hour
#   17:00 - 20:00: 16.18 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 4.85 vehicles/hour
#   12:00 - 17:00: 16.18 vehicles/hour
#   17:00 - 20:00: 16.18 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 4.85 vehicles/hour
#   12:00 - 17:00: 16.18 vehicles/hour
#   17:00 - 20:00: 16.18 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 4.85 vehicles/hour
#   12:00 - 17:00: 16.18 vehicles/hour
#   17:00 - 20:00: 16.18 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 6.47 vehicles/hour
#   12:00 - 17:00: 22.65 vehicles/hour
#   17:00 - 20:00: 25.88 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 6.47 vehicles/hour
#   12:00 - 17:00: 22.65 vehicles/hour
#   17:00 - 20:00: 25.88 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.01%
# Total Revenue: ₹133410.00
# Average Parking Duration: 59.10 minutes
# Average Inter-Arrival Time: 4.59 minutes
# Total Parked Customers: 3794
# Total Lost Customers: 949
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.52%
# 12-16:59: 4.57%
# 17-20:00: 5.60%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 4.61 vehicles/hour
#   12:00 - 17:00: 15.37 vehicles/hour
#   17:00 - 20:00: 15.37 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 4.61 vehicles/hour
#   12:00 - 17:00: 15.37 vehicles/hour
#   17:00 - 20:00: 15.37 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 4.61 vehicles/hour
#   12:00 - 17:00: 15.37 vehicles/hour
#   17:00 - 20:00: 15.37 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 4.61 vehicles/hour
#   12:00 - 17:00: 15.37 vehicles/hour
#   17:00 - 20:00: 15.37 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 4.61 vehicles/hour
#   12:00 - 17:00: 15.37 vehicles/hour
#   17:00 - 20:00: 15.37 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 6.15 vehicles/hour
#   12:00 - 17:00: 21.51 vehicles/hour
#   17:00 - 20:00: 24.59 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 6.15 vehicles/hour
#   12:00 - 17:00: 21.51 vehicles/hour
#   17:00 - 20:00: 24.59 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.23%
# Total Revenue: ₹130955.00
# Average Parking Duration: 61.41 minutes
# Average Inter-Arrival Time: 4.74 minutes
# Total Parked Customers: 3612
# Total Lost Customers: 916
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.58%
# 12-16:59: 4.35%
# 17-20:00: 5.73%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 4.38 vehicles/hour
#   12:00 - 17:00: 14.60 vehicles/hour
#   17:00 - 20:00: 14.60 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 4.38 vehicles/hour
#   12:00 - 17:00: 14.60 vehicles/hour
#   17:00 - 20:00: 14.60 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 4.38 vehicles/hour
#   12:00 - 17:00: 14.60 vehicles/hour
#   17:00 - 20:00: 14.60 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 4.38 vehicles/hour
#   12:00 - 17:00: 14.60 vehicles/hour
#   17:00 - 20:00: 14.60 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 4.38 vehicles/hour
#   12:00 - 17:00: 14.60 vehicles/hour
#   17:00 - 20:00: 14.60 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 5.84 vehicles/hour
#   12:00 - 17:00: 20.44 vehicles/hour
#   17:00 - 20:00: 23.36 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 5.84 vehicles/hour
#   12:00 - 17:00: 20.44 vehicles/hour
#   17:00 - 20:00: 23.36 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.63%
# Total Revenue: ₹119590.00
# Average Parking Duration: 58.72 minutes
# Average Inter-Arrival Time: 5.15 minutes
# Total Parked Customers: 3403
# Total Lost Customers: 831
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.17%
# 12-16:59: 4.02%
# 17-20:00: 5.18%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 4.16 vehicles/hour
#   12:00 - 17:00: 13.87 vehicles/hour
#   17:00 - 20:00: 13.87 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 4.16 vehicles/hour
#   12:00 - 17:00: 13.87 vehicles/hour
#   17:00 - 20:00: 13.87 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 4.16 vehicles/hour
#   12:00 - 17:00: 13.87 vehicles/hour
#   17:00 - 20:00: 13.87 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 4.16 vehicles/hour
#   12:00 - 17:00: 13.87 vehicles/hour
#   17:00 - 20:00: 13.87 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 4.16 vehicles/hour
#   12:00 - 17:00: 13.87 vehicles/hour
#   17:00 - 20:00: 13.87 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 5.55 vehicles/hour
#   12:00 - 17:00: 19.42 vehicles/hour
#   17:00 - 20:00: 22.19 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 5.55 vehicles/hour
#   12:00 - 17:00: 19.42 vehicles/hour
#   17:00 - 20:00: 22.19 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.33%
# Total Revenue: ₹110630.00
# Average Parking Duration: 59.96 minutes
# Average Inter-Arrival Time: 5.49 minutes
# Total Parked Customers: 3117
# Total Lost Customers: 845
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.06%
# 12-16:59: 3.79%
# 17-20:00: 4.78%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 3.95 vehicles/hour
#   12:00 - 17:00: 13.18 vehicles/hour
#   17:00 - 20:00: 13.18 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 3.95 vehicles/hour
#   12:00 - 17:00: 13.18 vehicles/hour
#   17:00 - 20:00: 13.18 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 3.95 vehicles/hour
#   12:00 - 17:00: 13.18 vehicles/hour
#   17:00 - 20:00: 13.18 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 3.95 vehicles/hour
#   12:00 - 17:00: 13.18 vehicles/hour
#   17:00 - 20:00: 13.18 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 3.95 vehicles/hour
#   12:00 - 17:00: 13.18 vehicles/hour
#   17:00 - 20:00: 13.18 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 5.27 vehicles/hour
#   12:00 - 17:00: 18.45 vehicles/hour
#   17:00 - 20:00: 21.08 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 5.27 vehicles/hour
#   12:00 - 17:00: 18.45 vehicles/hour
#   17:00 - 20:00: 21.08 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.32%
# Total Revenue: ₹104505.00
# Average Parking Duration: 58.02 minutes
# Average Inter-Arrival Time: 5.74 minutes
# Total Parked Customers: 3015
# Total Lost Customers: 722
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.04%
# 12-16:59: 3.47%
# 17-20:00: 4.50%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 3.76 vehicles/hour
#   12:00 - 17:00: 12.52 vehicles/hour
#   17:00 - 20:00: 12.52 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 3.76 vehicles/hour
#   12:00 - 17:00: 12.52 vehicles/hour
#   17:00 - 20:00: 12.52 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 3.76 vehicles/hour
#   12:00 - 17:00: 12.52 vehicles/hour
#   17:00 - 20:00: 12.52 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 3.76 vehicles/hour
#   12:00 - 17:00: 12.52 vehicles/hour
#   17:00 - 20:00: 12.52 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 3.76 vehicles/hour
#   12:00 - 17:00: 12.52 vehicles/hour
#   17:00 - 20:00: 12.52 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 5.01 vehicles/hour
#   12:00 - 17:00: 17.52 vehicles/hour
#   17:00 - 20:00: 20.03 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 5.01 vehicles/hour
#   12:00 - 17:00: 17.52 vehicles/hour
#   17:00 - 20:00: 20.03 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.92%
# Total Revenue: ₹102015.00
# Average Parking Duration: 58.73 minutes
# Average Inter-Arrival Time: 5.98 minutes
# Total Parked Customers: 2898
# Total Lost Customers: 721
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.90%
# 12-16:59: 3.39%
# 17-20:00: 4.40%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 3.57 vehicles/hour
#   12:00 - 17:00: 11.89 vehicles/hour
#   17:00 - 20:00: 11.89 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 3.57 vehicles/hour
#   12:00 - 17:00: 11.89 vehicles/hour
#   17:00 - 20:00: 11.89 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 3.57 vehicles/hour
#   12:00 - 17:00: 11.89 vehicles/hour
#   17:00 - 20:00: 11.89 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 3.57 vehicles/hour
#   12:00 - 17:00: 11.89 vehicles/hour
#   17:00 - 20:00: 11.89 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 3.57 vehicles/hour
#   12:00 - 17:00: 11.89 vehicles/hour
#   17:00 - 20:00: 11.89 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 4.76 vehicles/hour
#   12:00 - 17:00: 16.65 vehicles/hour
#   17:00 - 20:00: 19.03 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 4.76 vehicles/hour
#   12:00 - 17:00: 16.65 vehicles/hour
#   17:00 - 20:00: 19.03 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.65%
# Total Revenue: ₹99685.00
# Average Parking Duration: 61.13 minutes
# Average Inter-Arrival Time: 6.27 minutes
# Total Parked Customers: 2773
# Total Lost Customers: 678
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.95%
# 12-16:59: 3.39%
# 17-20:00: 4.27%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 3.39 vehicles/hour
#   12:00 - 17:00: 11.30 vehicles/hour
#   17:00 - 20:00: 11.30 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 3.39 vehicles/hour
#   12:00 - 17:00: 11.30 vehicles/hour
#   17:00 - 20:00: 11.30 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 3.39 vehicles/hour
#   12:00 - 17:00: 11.30 vehicles/hour
#   17:00 - 20:00: 11.30 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 3.39 vehicles/hour
#   12:00 - 17:00: 11.30 vehicles/hour
#   17:00 - 20:00: 11.30 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 3.39 vehicles/hour
#   12:00 - 17:00: 11.30 vehicles/hour
#   17:00 - 20:00: 11.30 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 4.52 vehicles/hour
#   12:00 - 17:00: 15.82 vehicles/hour
#   17:00 - 20:00: 18.07 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 4.52 vehicles/hour
#   12:00 - 17:00: 15.82 vehicles/hour
#   17:00 - 20:00: 18.07 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.76%
# Total Revenue: ₹94915.00
# Average Parking Duration: 61.46 minutes
# Average Inter-Arrival Time: 6.61 minutes
# Total Parked Customers: 2636
# Total Lost Customers: 649
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.76%
# 12-16:59: 3.36%
# 17-20:00: 4.11%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 3.22 vehicles/hour
#   12:00 - 17:00: 10.73 vehicles/hour
#   17:00 - 20:00: 10.73 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 3.22 vehicles/hour
#   12:00 - 17:00: 10.73 vehicles/hour
#   17:00 - 20:00: 10.73 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 3.22 vehicles/hour
#   12:00 - 17:00: 10.73 vehicles/hour
#   17:00 - 20:00: 10.73 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 3.22 vehicles/hour
#   12:00 - 17:00: 10.73 vehicles/hour
#   17:00 - 20:00: 10.73 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 3.22 vehicles/hour
#   12:00 - 17:00: 10.73 vehicles/hour
#   17:00 - 20:00: 10.73 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 4.29 vehicles/hour
#   12:00 - 17:00: 15.02 vehicles/hour
#   17:00 - 20:00: 17.17 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 4.29 vehicles/hour
#   12:00 - 17:00: 15.02 vehicles/hour
#   17:00 - 20:00: 17.17 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.67%
# Total Revenue: ₹85545.00
# Average Parking Duration: 57.96 minutes
# Average Inter-Arrival Time: 6.97 minutes
# Total Parked Customers: 2465
# Total Lost Customers: 566
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.66%
# 12-16:59: 2.98%
# 17-20:00: 3.53%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 3.06 vehicles/hour
#   12:00 - 17:00: 10.20 vehicles/hour
#   17:00 - 20:00: 10.20 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 3.06 vehicles/hour
#   12:00 - 17:00: 10.20 vehicles/hour
#   17:00 - 20:00: 10.20 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 3.06 vehicles/hour
#   12:00 - 17:00: 10.20 vehicles/hour
#   17:00 - 20:00: 10.20 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 3.06 vehicles/hour
#   12:00 - 17:00: 10.20 vehicles/hour
#   17:00 - 20:00: 10.20 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 3.06 vehicles/hour
#   12:00 - 17:00: 10.20 vehicles/hour
#   17:00 - 20:00: 10.20 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 4.08 vehicles/hour
#   12:00 - 17:00: 14.27 vehicles/hour
#   17:00 - 20:00: 16.31 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 4.08 vehicles/hour
#   12:00 - 17:00: 14.27 vehicles/hour
#   17:00 - 20:00: 16.31 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.28%
# Total Revenue: ₹85305.00
# Average Parking Duration: 60.72 minutes
# Average Inter-Arrival Time: 7.42 minutes
# Total Parked Customers: 2374
# Total Lost Customers: 567
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.67%
# 12-16:59: 2.99%
# 17-20:00: 3.63%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 2.91 vehicles/hour
#   12:00 - 17:00: 9.69 vehicles/hour
#   17:00 - 20:00: 9.69 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 2.91 vehicles/hour
#   12:00 - 17:00: 9.69 vehicles/hour
#   17:00 - 20:00: 9.69 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 2.91 vehicles/hour
#   12:00 - 17:00: 9.69 vehicles/hour
#   17:00 - 20:00: 9.69 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 2.91 vehicles/hour
#   12:00 - 17:00: 9.69 vehicles/hour
#   17:00 - 20:00: 9.69 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 2.91 vehicles/hour
#   12:00 - 17:00: 9.69 vehicles/hour
#   17:00 - 20:00: 9.69 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 3.87 vehicles/hour
#   12:00 - 17:00: 13.56 vehicles/hour
#   17:00 - 20:00: 15.50 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 3.87 vehicles/hour
#   12:00 - 17:00: 13.56 vehicles/hour
#   17:00 - 20:00: 15.50 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.65%
# Total Revenue: ₹82090.00
# Average Parking Duration: 60.79 minutes
# Average Inter-Arrival Time: 7.53 minutes
# Total Parked Customers: 2277
# Total Lost Customers: 557
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.52%
# 12-16:59: 2.79%
# 17-20:00: 3.58%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 2.76 vehicles/hour
#   12:00 - 17:00: 9.20 vehicles/hour
#   17:00 - 20:00: 9.20 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 2.76 vehicles/hour
#   12:00 - 17:00: 9.20 vehicles/hour
#   17:00 - 20:00: 9.20 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 2.76 vehicles/hour
#   12:00 - 17:00: 9.20 vehicles/hour
#   17:00 - 20:00: 9.20 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 2.76 vehicles/hour
#   12:00 - 17:00: 9.20 vehicles/hour
#   17:00 - 20:00: 9.20 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 2.76 vehicles/hour
#   12:00 - 17:00: 9.20 vehicles/hour
#   17:00 - 20:00: 9.20 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 3.68 vehicles/hour
#   12:00 - 17:00: 12.88 vehicles/hour
#   17:00 - 20:00: 14.72 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 3.68 vehicles/hour
#   12:00 - 17:00: 12.88 vehicles/hour
#   17:00 - 20:00: 14.72 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.75%
# Total Revenue: ₹76565.00
# Average Parking Duration: 62.29 minutes
# Average Inter-Arrival Time: 8.35 minutes
# Total Parked Customers: 2088
# Total Lost Customers: 514
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.41%
# 12-16:59: 2.68%
# 17-20:00: 3.39%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 2.62 vehicles/hour
#   12:00 - 17:00: 8.74 vehicles/hour
#   17:00 - 20:00: 8.74 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 2.62 vehicles/hour
#   12:00 - 17:00: 8.74 vehicles/hour
#   17:00 - 20:00: 8.74 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 2.62 vehicles/hour
#   12:00 - 17:00: 8.74 vehicles/hour
#   17:00 - 20:00: 8.74 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 2.62 vehicles/hour
#   12:00 - 17:00: 8.74 vehicles/hour
#   17:00 - 20:00: 8.74 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 2.62 vehicles/hour
#   12:00 - 17:00: 8.74 vehicles/hour
#   17:00 - 20:00: 8.74 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 3.50 vehicles/hour
#   12:00 - 17:00: 12.24 vehicles/hour
#   17:00 - 20:00: 13.99 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 3.50 vehicles/hour
#   12:00 - 17:00: 12.24 vehicles/hour
#   17:00 - 20:00: 13.99 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.80%
# Total Revenue: ₹74175.00
# Average Parking Duration: 59.31 minutes
# Average Inter-Arrival Time: 8.60 minutes
# Total Parked Customers: 2086
# Total Lost Customers: 483
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.41%
# 12-16:59: 2.58%
# 17-20:00: 3.13%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 2.49 vehicles/hour
#   12:00 - 17:00: 8.30 vehicles/hour
#   17:00 - 20:00: 8.30 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 2.49 vehicles/hour
#   12:00 - 17:00: 8.30 vehicles/hour
#   17:00 - 20:00: 8.30 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 2.49 vehicles/hour
#   12:00 - 17:00: 8.30 vehicles/hour
#   17:00 - 20:00: 8.30 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 2.49 vehicles/hour
#   12:00 - 17:00: 8.30 vehicles/hour
#   17:00 - 20:00: 8.30 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 2.49 vehicles/hour
#   12:00 - 17:00: 8.30 vehicles/hour
#   17:00 - 20:00: 8.30 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 3.32 vehicles/hour
#   12:00 - 17:00: 11.63 vehicles/hour
#   17:00 - 20:00: 13.29 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 3.32 vehicles/hour
#   12:00 - 17:00: 11.63 vehicles/hour
#   17:00 - 20:00: 13.29 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.61%
# Total Revenue: ₹67560.00
# Average Parking Duration: 59.51 minutes
# Average Inter-Arrival Time: 9.02 minutes
# Total Parked Customers: 1911
# Total Lost Customers: 496
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.25%
# 12-16:59: 2.49%
# 17-20:00: 2.72%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 2.37 vehicles/hour
#   12:00 - 17:00: 7.89 vehicles/hour
#   17:00 - 20:00: 7.89 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 2.37 vehicles/hour
#   12:00 - 17:00: 7.89 vehicles/hour
#   17:00 - 20:00: 7.89 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 2.37 vehicles/hour
#   12:00 - 17:00: 7.89 vehicles/hour
#   17:00 - 20:00: 7.89 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 2.37 vehicles/hour
#   12:00 - 17:00: 7.89 vehicles/hour
#   17:00 - 20:00: 7.89 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 2.37 vehicles/hour
#   12:00 - 17:00: 7.89 vehicles/hour
#   17:00 - 20:00: 7.89 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 3.16 vehicles/hour
#   12:00 - 17:00: 11.04 vehicles/hour
#   17:00 - 20:00: 12.62 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 3.16 vehicles/hour
#   12:00 - 17:00: 11.04 vehicles/hour
#   17:00 - 20:00: 12.62 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.96%
# Total Revenue: ₹64265.00
# Average Parking Duration: 59.42 minutes
# Average Inter-Arrival Time: 9.53 minutes
# ...
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 28.36%
# Total Revenue: ₹1730.00
# Average Parking Duration: 57.06 minutes
# Average Inter-Arrival Time: 563.68 minutes
# Total Parked Customers: 48
# Total Lost Customers: 19
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.37%
# 12-16:59: 0.39%
# 17-20:00: 0.46%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.88%
# Total Revenue: ₹1425.00
# Average Parking Duration: 45.27 minutes
# Average Inter-Arrival Time: 635.65 minutes
# Total Parked Customers: 50
# Total Lost Customers: 14
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.44%
# 12-16:59: 0.39%
# 17-20:00: 0.36%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 23.61%
# Total Revenue: ₹2015.00
# Average Parking Duration: 62.55 minutes
# Average Inter-Arrival Time: 473.74 minutes
# Total Parked Customers: 55
# Total Lost Customers: 17
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.36%
# 12-16:59: 0.52%
# 17-20:00: 0.25%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 25.37%
# Total Revenue: ₹1900.00
# Average Parking Duration: 65.91 minutes
# Average Inter-Arrival Time: 698.84 minutes
# Total Parked Customers: 50
# Total Lost Customers: 17
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.43%
# 12-16:59: 0.32%
# 17-20:00: 0.53%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 25.86%
# Total Revenue: ₹1520.00
# Average Parking Duration: 62.03 minutes
# Average Inter-Arrival Time: 847.95 minutes
# Total Parked Customers: 43
# Total Lost Customers: 15
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.56%
# 12-16:59: 0.34%
# 17-20:00: 0.34%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 26.39%
# Total Revenue: ₹2155.00
# Average Parking Duration: 70.98 minutes
# Average Inter-Arrival Time: 488.64 minutes
# Total Parked Customers: 53
# Total Lost Customers: 19
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.34%
# 12-16:59: 0.49%
# 17-20:00: 0.33%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 14.04%
# Total Revenue: ₹1530.00
# Average Parking Duration: 52.14 minutes
# Average Inter-Arrival Time: 716.56 minutes
# Total Parked Customers: 49
# Total Lost Customers: 8
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.58%
# 12-16:59: 0.34%
# 17-20:00: 0.27%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.05%
# Total Revenue: ₹1790.00
# Average Parking Duration: 55.61 minutes
# Average Inter-Arrival Time: 519.82 minutes
# Total Parked Customers: 51
# Total Lost Customers: 12
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.45%
# 12-16:59: 0.31%
# 17-20:00: 0.47%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 16.44%
# Total Revenue: ₹2350.00
# Average Parking Duration: 66.08 minutes
# Average Inter-Arrival Time: 553.51 minutes
# Total Parked Customers: 61
# Total Lost Customers: 12
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.46%
# 12-16:59: 0.41%
# 17-20:00: 0.32%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 23.53%
# Total Revenue: ₹2025.00
# Average Parking Duration: 70.11 minutes
# Average Inter-Arrival Time: 547.67 minutes
# Total Parked Customers: 52
# Total Lost Customers: 16
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.32%
# 12-16:59: 0.32%
# 17-20:00: 0.63%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 16.42%
# Total Revenue: ₹1755.00
# Average Parking Duration: 52.41 minutes
# Average Inter-Arrival Time: 561.63 minutes
# Total Parked Customers: 56
# Total Lost Customers: 11
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.41%
# 12-16:59: 0.41%
# 17-20:00: 0.37%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Adjusting arrival rates...
# Adjusting arrival rates with factor: 0.95
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 9.84%
# Total Revenue: ₹2185.00
# Average Parking Duration: 70.34 minutes
# Average Inter-Arrival Time: 567.60 minutes
# Total Parked Customers: 55
# Total Lost Customers: 6
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.54%
# 12-16:59: 0.40%
# 17-20:00: 0.19%
#
# Updated Arrival Rates by Time Slot:
#
# Sunday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Monday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Tuesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Wednesday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Thursday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Friday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
#
# Saturday:
#   8:00 - 12:00: 0.10 vehicles/hour
#   12:00 - 17:00: 0.10 vehicles/hour
#   17:00 - 20:00: 0.10 vehicles/hour
# Lost customer percentage is within the acceptable range: 9.84%
